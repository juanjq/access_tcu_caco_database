# %%
import matplotlib.pyplot as plt
import matplotlib.dates as mdates
import numpy as np
from datetime import datetime, timedelta
import pymongo
import pickle
import bson
import subprocess

# Other external scripts
import lst1_mongodb_example
import utils

client_tcu  = pymongo.MongoClient("localhost:27017")
client_caco = pymongo.MongoClient("localhost:27018")

read_db = False

# %% [markdown]
# #### TCU properties:

# %%
# !python lst1_mongodb_example.py --list-available

# %% [markdown]
# #### CaCo databases and collections:

# %%
# client_caco = pymongo.MongoClient("localhost:27018")

# all_databases = np.sort(client_caco.list_database_names())

# print(f"--- {'':^40s} ---")
# print(f"--- {'Available CaCo databases and collections':^40s} ---")
# print(f"--- {'':^40s} ---")
# for database in all_databases:
#     print(f"\n--- {f'Database - {database}':^40s} ---")
    
#     all_collections = np.sort(client_caco[database].list_collection_names())
#     for i, collection in enumerate(all_collections):
#         print(f"{i:4d} : {collection}")

# %% [markdown]
# #### All properties from CaCo database:

# %%
# # Selecting CaCo database
# caco_db = client_caco.CACO

# dict_caco_names = {}
# all_collections = np.sort(caco_db.list_collection_names())
# for coll_name in all_collections:
#     coll = caco_db[coll_name]
#     if coll not in ["STATE", "RUN_INFORMATION"] and "week" in coll_name:
    
#         print(f"\n--- {f'Collection - {coll_name}':^40s} ---")
#         names = coll.distinct("name")
        
#         dict_caco_names[coll_name.replace("week", "min")] = names
#         for i,n in enumerate(names):
#             print(f"{i:4.0f} : {n}")

# %%
# %%time

# def get_records(mongo_client, database_name, collection_name, query):
#     collection = mongo_client[database_name][collection_name]
#     response   = collection.find(query)
#     records = tuple(doc for doc in response)    
#     return records
# query = None

# if read_db:
    
#     # Reading TCU database
#     print("Reading TCU database")
#     records_tcu  = get_records(client_tcu,  "lst1_obs_summary", "camera", query)

#     # Reading CaCo database
#     print("Reading CaCo database")
#     records_caco = get_records(client_caco, "CACO", "RUN_INFORMATION", query)  
    
#     # Saving the objects
#     with open("objects/records_tcu.pkl", "wb") as f:
#         pickle.dump(records_tcu, f, pickle.HIGHEST_PROTOCOL)
#     with open("objects/records_caco.pkl", "wb") as f:
#         pickle.dump(records_caco, f, pickle.HIGHEST_PROTOCOL)

# else:
    
#     # Reading the saved objects
#     with open("objects/records_tcu.pkl", "rb") as f:
#         records_tcu = pickle.load(f)
#     with open("objects/records_caco.pkl", "rb") as f:
#         records_caco = pickle.load(f)

# %%
dict_caco_states = {0 : "OFF", 1 : "DATA_MONITORING", 2 : "MONITORED", 3 : "SAFE", 4 : "STANDBY",
                    5 : "READY", 6 : "OBSERVING", 7 : "TPOINT", 8 : "UNDEFINED", 9 : "TRANSITIONAL", 10 : "ERROR"}
dict_caco_state_colors = {0 : "k", 1 : "darkviolet", 2 : "darkviolet", 3 : "lime", 4 : "gold",
                          5 : "c", 6 : "darkblue", 7 : "b", 8 : "r", 9 : "darkorange", 10 : "r"}

variable_tcu = "CameraControl_FSM_state"
tstart = datetime.fromisoformat("2024-02-25-00:00:00")
tstop  = datetime.fromisoformat("2024-04-01-00:00:00")


out_tcu = lst1_mongodb_example.get_entries(client_tcu, variable_tcu, astropy_time=False, tstart=tstart, tstop=tstop)
date_tcu, value_tcu = np.array(out_tcu["time"]), np.array(out_tcu["value"])

value_str_tcu = np.array([dict_caco_states[v] for v in value_tcu])

# %% [markdown]
# #### Extracting the timespans of each state

# %%
# Creating a timespan dictionary for each key
timespans_dict = {}
for key in dict_caco_states.keys():
    timespans_dict[key] = {"tstart" : [], "tstop" : [], "tspan" : []}

before_state = value_tcu[0]
initial_time = date_tcu[0]
for i in range(len(value_tcu))[1:]:
    
    actual_state = value_tcu[i]

    if before_state != actual_state:
        final_time = date_tcu[i]

        timespans_dict[actual_state]["tstart"].append(initial_time)
        timespans_dict[actual_state]["tstop"].append(final_time)
        
        timespans_dict[actual_state]["tspan"].append((final_time - initial_time).total_seconds())

        initial_time = date_tcu[i]
        
    before_state = actual_state

# %% [markdown]
# #### Getting all TCU property names

# %%
string_properties = !python lst1_mongodb_example.py --list-available
all_tcu_properties = np.array([s.split(" : ")[-1] for s in string_properties[3:]])

camera_related_tcu_properties = []
non_camera_properties_prefix = ["AMC_", "AuxControl_", "CDM2_", "DriveControl_", "SecurityBrokerControl_"]

for p in all_tcu_properties:
    flag_camera = True
    for non_p in non_camera_properties_prefix:
        if non_p in p:
            flag_camera = False
            break
    if flag_camera:
        camera_related_tcu_properties.append(p)

print(f"There are {len(all_tcu_properties)} TCU properties in total")
print(f"There are {len(camera_related_tcu_properties)} TCU Camera-related properties in total")
# Out:
# There are 1159 TCU properties in total
# There are 498 TCU Camera-related properties in total

# %% [markdown]
# #### **Here we are doing the trick of extracting the size of a chunk for each property of the TCU database**

# %%
dict_tcu_property_bytes = {}
for p in camera_related_tcu_properties:
    dict_tcu_property_bytes[p] = 0
    
# Taking the main collections and chunks pointers
property_collection = client_tcu['bridgesmonitoring']['properties']
chunk_collection = client_tcu['bridgesmonitoring']['chunks']

for ip, _property in enumerate(camera_related_tcu_properties):
    
    descriptors = property_collection.find({'property_name': _property})

    for desc in descriptors:
        query = {'pid': desc['_id']}
        query.update({"begin": {"$gte": tstart}, "end": {"$lte": tstop}})

        chunks = chunk_collection.find(query)
        for chunk in chunks:

            bson_data = bson.BSON.encode(chunk)
            size_in_bytes = len(bson_data)

            dict_tcu_property_bytes[_property] = size_in_bytes
            
            break
    print(f"{ip/len(camera_related_tcu_properties)*100:2.3f}% Extracting bytes of {_property} --> {size_in_bytes} b")
# Out:
# 0.000% Extracting bytes of CalibrationBox_BG_InterCalibration_Mean --> 127 b
# 0.201% Extracting bytes of CalibrationBox_DewPoint --> 127 b
# 0.402% Extracting bytes of CalibrationBox_Error_BG_InterCalibration_Mean --> 127 b
# 0.602% Extracting bytes of CalibrationBox_Error_InterCalibration_Mean --> 127 b
# 0.803% Extracting bytes of CalibrationBox_FSM_state --> 127 b
# 1.004% Extracting bytes of CalibrationBox_FSM_transition --> 127 b
# 1.205% Extracting bytes of CalibrationBox_Humidity --> 127 b
# 1.406% Extracting bytes of CalibrationBox_InterCalibration_Mean --> 127 b
# 1.606% Extracting bytes of CalibrationBox_LaserErrorCode --> 127 b
# 1.807% Extracting bytes of CalibrationBox_LaserInfoCode --> 127 b
# 2.008% Extracting bytes of CalibrationBox_LaserStatus --> 127 b
# 2.209% Extracting bytes of CalibrationBox_LaserTrigParameters --> 127 b
# 2.410% Extracting bytes of CalibrationBox_PedStatus --> 127 b
# 2.610% Extracting bytes of CalibrationBox_PedTrigParameters --> 127 b
# 2.811% Extracting bytes of CalibrationBox_PowerStatus --> 127 b
# 3.012% Extracting bytes of CalibrationBox_PowerStatusLR --> 127 b
# 3.213% Extracting bytes of CalibrationBox_Pressure --> 127 b
# 3.414% Extracting bytes of CalibrationBox_Temperature --> 127 b
# 3.614% Extracting bytes of CalibrationBox_WheelPosition --> 127 b
# 3.815% Extracting bytes of Calibration_CalibrationBox_Humidity --> 127 b
# 4.016% Extracting bytes of Calibration_CalibrationBox_LaserErrorCode --> 127 b
# 4.217% Extracting bytes of Calibration_CalibrationBox_LaserInfoCode --> 127 b
# 4.418% Extracting bytes of Calibration_CalibrationBox_LaserStatus --> 127 b
# 4.618% Extracting bytes of Calibration_CalibrationBox_LaserTrigParameters --> 127 b
# 4.819% Extracting bytes of Calibration_CalibrationBox_PowerStatus --> 127 b
# 5.020% Extracting bytes of Calibration_CalibrationBox_Pressure --> 127 b
# 5.221% Extracting bytes of Calibration_CalibrationBox_Temperature --> 127 b
# 5.422% Extracting bytes of Calibration_CalibrationBox_WheelPosition --> 127 b
# 5.622% Extracting bytes of CameraControl_CBOXControl_state --> 121 b
# 5.823% Extracting bytes of CameraControl_FSM_is_transit --> 118 b
# 6.024% Extracting bytes of CameraControl_FSM_is_warm_up --> 118 b
# 6.225% Extracting bytes of CameraControl_FSM_previous_state --> 121 b
# 6.426% Extracting bytes of CameraControl_FSM_state --> 121 b
# 6.627% Extracting bytes of CameraControl_InstrumentProtection_mode --> 127 b
# 6.827% Extracting bytes of CameraControl_InstrumentProtection_status --> 121 b
# 7.028% Extracting bytes of CameraControl_MessageAdviser_last_message --> 121 b
# 7.229% Extracting bytes of CameraControl_ModulesAvailable_CBOX_valid_connection --> 118 b
# 7.430% Extracting bytes of CameraControl_ModulesAvailable_CLUS_valid_connection --> 118 b
# 7.631% Extracting bytes of CameraControl_ModulesAvailable_DAQ_valid_connection --> 118 b
# 7.831% Extracting bytes of CameraControl_ModulesAvailable_ECC_valid_connection --> 118 b
# 8.032% Extracting bytes of CameraControl_ModulesAvailable_Sphe_valid_connection --> 118 b
# 8.233% Extracting bytes of CameraControl_ModulesAvailable_TIB_valid_connection --> 118 b
# 8.434% Extracting bytes of CameraControl_ModulesAvailable_UCTS_valid_connection --> 118 b
# 8.635% Extracting bytes of CameraControl_ModulesStatus_CLUSCO --> 121 b
# 8.835% Extracting bytes of CameraControl_ModulesStatus_CS --> 121 b
# 9.036% Extracting bytes of CameraControl_ModulesStatus_DAQ --> 121 b
# 9.237% Extracting bytes of CameraControl_ModulesStatus_ECC --> 121 b
# 9.438% Extracting bytes of CameraControl_ModulesStatus_SIS --> 121 b
# 9.639% Extracting bytes of CameraControl_ModulesStatus_TIB --> 121 b
# 9.839% Extracting bytes of CameraControl_ModulesStatus_UCTS --> 121 b
# 10.040% Extracting bytes of CameraControl_RunUtils_is_test --> 118 b
# 10.241% Extracting bytes of CameraControl_RunUtils_run_number --> 121 b
# 10.442% Extracting bytes of CameraControl_UserAdviser_message --> 122 b
# 10.643% Extracting bytes of CameraControl__ControlLoopTimeStamp --> 122 b
# 10.843% Extracting bytes of CameraControl_heartbeat_caco_timestamp --> 121 b
# 11.044% Extracting bytes of CameraControl_heartbeat_enabled --> 118 b
# 11.245% Extracting bytes of CameraControl_heartbeat_time_limit --> 118 b
# 11.446% Extracting bytes of CameraControl_heartbeat_times_failed --> 118 b
# 11.647% Extracting bytes of CameraControl_information_MessageAdviser_last_message --> 179 b
# 11.847% Extracting bytes of CameraControl_information_error_state --> 121 b
# 12.048% Extracting bytes of Camera_CalibrationBox_BG_InterCalibration_Mean --> 125 b
# 12.249% Extracting bytes of Camera_CalibrationBox_DewPoint --> 125 b
# 12.450% Extracting bytes of Camera_CalibrationBox_Error_BG_InterCalibration_Mean --> 125 b
# 12.651% Extracting bytes of Camera_CalibrationBox_Error_InterCalibration_Mean --> 125 b
# 12.851% Extracting bytes of Camera_CalibrationBox_Humidity --> 189 b
# 13.052% Extracting bytes of Camera_CalibrationBox_InterCalibration_Mean --> 125 b
# 13.253% Extracting bytes of Camera_CalibrationBox_LaserErrorCode --> 122 b
# 13.454% Extracting bytes of Camera_CalibrationBox_LaserInfoCode --> 122 b
# 13.655% Extracting bytes of Camera_CalibrationBox_LaserStatus --> 121 b
# 13.855% Extracting bytes of Camera_CalibrationBox_LaserTrigParameters --> 136 b
# 14.056% Extracting bytes of Camera_CalibrationBox_PedRndTrigParameter --> 125 b
# 14.257% Extracting bytes of Camera_CalibrationBox_PedStatus --> 121 b
# 14.458% Extracting bytes of Camera_CalibrationBox_PedTrigParameters --> 155 b
# 14.659% Extracting bytes of Camera_CalibrationBox_PowerStatus --> 118 b
# 14.859% Extracting bytes of Camera_CalibrationBox_PowerStatusLR --> 118 b
# 15.060% Extracting bytes of Camera_CalibrationBox_Pressure --> 125 b
# 15.261% Extracting bytes of Camera_CalibrationBox_Temperature --> 157 b
# 15.462% Extracting bytes of Camera_CalibrationBox_WheelPosition --> 144 b
# 15.663% Extracting bytes of Camera_UCTS_ConfigurationParameters_CDTS_MAC_Address --> 144 b
# 15.863% Extracting bytes of Camera_UCTS_ConfigurationParameters_OPCUA_server_IP_Address --> 144 b
# 16.064% Extracting bytes of Camera_UCTS_ConfigurationParameters_UCTS_IP_Address --> 144 b
# 16.265% Extracting bytes of Camera_UCTS_Configuration_UctsIpAddr --> 130 b
# 16.466% Extracting bytes of Camera_UCTS_FSM_state --> 130 b
# 16.667% Extracting bytes of Camera_UCTS_FSM_transition --> 130 b
# 16.867% Extracting bytes of Camera_UCTS_HardwareConfig_state --> 130 b
# 17.068% Extracting bytes of Camera_UCTS_SNMPParameters_SNMP_Port_Link_Status --> 130 b
# 17.269% Extracting bytes of Camera_UCTS_SNMPParameters_SNMP_Temperature --> 130 b
# 17.470% Extracting bytes of Camera_UCTS_SNMPParameters_SNMP_Time_TAI --> 130 b
# 17.671% Extracting bytes of Camera_UCTS_SNMPParameters_SNMP_Up_Time --> 130 b
# 17.871% Extracting bytes of Camera_UCTS_SNMPParameters_SNMP_wrpc_Sw_Version --> 130 b
# 18.072% Extracting bytes of Camera_UCTS_SNMP_BusyCount --> 121 b
# 18.273% Extracting bytes of Camera_UCTS_SNMP_DstIpAddr --> 168 b
# 18.474% Extracting bytes of Camera_UCTS_SNMP_DstMacAddr --> 122 b
# 18.675% Extracting bytes of Camera_UCTS_SNMP_DstPort --> 121 b
# 18.876% Extracting bytes of Camera_UCTS_SNMP_EventCount --> 121 b
# 19.076% Extracting bytes of Camera_UCTS_SNMP_PortLinkStatus --> 124 b
# 19.277% Extracting bytes of Camera_UCTS_SNMP_Status --> 149 b
# 19.478% Extracting bytes of Camera_UCTS_SNMP_Temperature --> 221 b
# 19.679% Extracting bytes of Camera_UCTS_SNMP_Throttle --> 121 b
# 19.880% Extracting bytes of Camera_UCTS_SNMP_TimeTAI --> 121 b
# 20.080% Extracting bytes of Camera_UCTS_SNMP_UpTime --> 249 b
# 20.281% Extracting bytes of Camera_UCTS_SNMP_WrpcSwVersion --> 122 b
# 20.482% Extracting bytes of Camera__ControlLoopTimeStamp --> 122 b
# 20.683% Extracting bytes of Camera__Enable_Heart_Beat --> 122 b
# 20.884% Extracting bytes of Camera__Error_Heart_Beat --> 122 b
# 21.084% Extracting bytes of Camera__Heart_Beat --> 122 b
# 21.285% Extracting bytes of ECC_FSM_state --> 121 b
# 21.486% Extracting bytes of ECC_FSM_transition --> 121 b
# 21.687% Extracting bytes of ECC_Monitoring_AirValve_AirRegulationStatus --> 118 b
# 21.888% Extracting bytes of ECC_Monitoring_AirValve_AirValveError --> 118 b
# 22.088% Extracting bytes of ECC_Monitoring_AirValve_AirValveStatus --> 118 b
# 22.289% Extracting bytes of ECC_Monitoring_Alarm_Status_Alarm_Back_Door --> 118 b
# 22.490% Extracting bytes of ECC_Monitoring_Alarm_Status_Alarm_Caco_HeartBeat --> 118 b
# 22.691% Extracting bytes of ECC_Monitoring_Alarm_Status_Alarm_ChillerHeating --> 118 b
# 22.892% Extracting bytes of ECC_Monitoring_Alarm_Status_Alarm_Current_24V_PSU1 --> 118 b
# 23.092% Extracting bytes of ECC_Monitoring_Alarm_Status_Alarm_Current_24V_PSU2 --> 118 b
# 23.293% Extracting bytes of ECC_Monitoring_Alarm_Status_Alarm_Flowmeter --> 118 b
# 23.494% Extracting bytes of ECC_Monitoring_Alarm_Status_Alarm_Front_Door --> 118 b
# 23.695% Extracting bytes of ECC_Monitoring_Alarm_Status_Alarm_General_current --> 118 b
# 23.896% Extracting bytes of ECC_Monitoring_Alarm_Status_Alarm_Humidity --> 118 b
# 24.096% Extracting bytes of ECC_Monitoring_Alarm_Status_Alarm_IR --> 118 b
# 24.297% Extracting bytes of ECC_Monitoring_Alarm_Status_Alarm_Light --> 118 b
# 24.498% Extracting bytes of ECC_Monitoring_Alarm_Status_Alarm_PDB --> 118 b
# 24.699% Extracting bytes of ECC_Monitoring_Alarm_Status_Alarm_Pressure --> 118 b
# 24.900% Extracting bytes of ECC_Monitoring_Alarm_Status_Alarm_Smoke --> 118 b
# 25.100% Extracting bytes of ECC_Monitoring_Alarm_Status_Alarm_Spare --> 136 b
# 25.301% Extracting bytes of ECC_Monitoring_Alarm_Status_Alarm_Temperature --> 118 b
# 25.502% Extracting bytes of ECC_Monitoring_Alarm_Status_Alarm_WaterLeak --> 118 b
# 25.703% Extracting bytes of ECC_Monitoring_Alarm_Status_Alarm_WaterPressure --> 118 b
# 25.904% Extracting bytes of ECC_Monitoring_Alarm_Status_WarningFanTachymeter --> 118 b
# 26.104% Extracting bytes of ECC_Monitoring_Alarm_Status_Warning_Temperature --> 118 b
# 26.305% Extracting bytes of ECC_Monitoring_Chiller_CommunicationStatus --> 121 b
# 26.506% Extracting bytes of ECC_Monitoring_Chiller_ECC_RegulationStatus --> 118 b
# 26.707% Extracting bytes of ECC_Monitoring_Chiller_ECC_RegulationSwitchCode --> 121 b
# 26.908% Extracting bytes of ECC_Monitoring_Chiller_ECC_RegulationSwitchString --> 157 b
# 27.108% Extracting bytes of ECC_Monitoring_Chiller_ErrorCode --> 123 b
# 27.309% Extracting bytes of ECC_Monitoring_Chiller_FSMState --> 121 b
# 27.510% Extracting bytes of ECC_Monitoring_Chiller_GeneralStatus --> 123 b
# 27.711% Extracting bytes of ECC_Monitoring_Chiller_HP_LP_Pressure --> 121 b
# 27.912% Extracting bytes of ECC_Monitoring_Chiller_Heating_Cooling_Countdown --> 121 b
# 28.112% Extracting bytes of ECC_Monitoring_Chiller_RelayStatus --> 121 b
# 28.313% Extracting bytes of ECC_Monitoring_Chiller_TemperatureAmbiant --> 125 b
# 28.514% Extracting bytes of ECC_Monitoring_Chiller_TemperatureEvaporatorWater --> 125 b
# 28.715% Extracting bytes of ECC_Monitoring_Chiller_TemperatureTankWater --> 125 b
# 28.916% Extracting bytes of ECC_Monitoring_CommissioningMode --> 125 b
# 29.116% Extracting bytes of ECC_Monitoring_CoolingValve_CoolingRegulationStatus --> 118 b
# 29.317% Extracting bytes of ECC_Monitoring_CoolingValve_CoolingValveError --> 118 b
# 29.518% Extracting bytes of ECC_Monitoring_CoolingValve_CoolingValveStatus --> 121 b
# 29.719% Extracting bytes of ECC_Monitoring_Debug_ECC_ECC_Program_Version --> 133 b
# 29.920% Extracting bytes of ECC_Monitoring_ECC_Error_ErrorDescription --> 123 b
# 30.120% Extracting bytes of ECC_Monitoring_ECC_Error_ErrorNumber --> 121 b
# 30.321% Extracting bytes of ECC_Monitoring_ECC_Error_ErrorResolution --> 123 b
# 30.522% Extracting bytes of ECC_Monitoring_Front_fans_FanTachymeterError_ --> 264 b
# 30.723% Extracting bytes of ECC_Monitoring_Front_fans_FanTachymeter_ --> 8267 b
# 30.924% Extracting bytes of ECC_Monitoring_Front_fans_GeneralStatus --> 121 b
# 31.124% Extracting bytes of ECC_Monitoring_IntelligentRelay_Current --> 210 b
# 31.325% Extracting bytes of ECC_Monitoring_IntelligentRelay_Status --> 178 b
# 31.526% Extracting bytes of ECC_Monitoring_IntelligentRelay_StatusMonitoring --> 178 b
# 31.727% Extracting bytes of ECC_Monitoring_IntelligentRelay_Voltage --> 210 b
# 31.928% Extracting bytes of ECC_Monitoring_LEDPositions_GeneralStatus --> 118 b
# 32.129% Extracting bytes of ECC_Monitoring_LEDPositions_Led_ --> 240 b
# 32.329% Extracting bytes of ECC_Monitoring_PDB_ActiveEnergy400V --> 125 b
# 32.530% Extracting bytes of ECC_Monitoring_PDB_ApparentEnergy400V --> 125 b
# 32.731% Extracting bytes of ECC_Monitoring_PDB_Cosinus400V --> 578 b
# 32.932% Extracting bytes of ECC_Monitoring_PDB_CurrentSensors_CurrentSupply230V --> 125 b
# 33.133% Extracting bytes of ECC_Monitoring_PDB_CurrentSensors_CurrentSupply400V_L --> 1343 b
# 33.333% Extracting bytes of ECC_Monitoring_PDB_Frequency400V --> 125 b
# 33.534% Extracting bytes of ECC_Monitoring_PDB_PDBStatus_Led_Control --> 118 b
# 33.735% Extracting bytes of ECC_Monitoring_PDB_PDBStatus_OF_MOTOR_400V --> 118 b
# 33.936% Extracting bytes of ECC_Monitoring_PDB_PDBStatus_OF_MOTOR_AUX_400V --> 118 b
# 34.137% Extracting bytes of ECC_Monitoring_PDB_PDBStatus_OF_MOTOR_AUX_SAI --> 118 b
# 34.337% Extracting bytes of ECC_Monitoring_PDB_PDBStatus_OF_MOTOR_SAI --> 118 b
# 34.538% Extracting bytes of ECC_Monitoring_PDB_PDBStatus_SD_MOTOR_400V --> 118 b
# 34.739% Extracting bytes of ECC_Monitoring_PDB_PDBStatus_SD_MOTOR_SAI --> 118 b
# 34.940% Extracting bytes of ECC_Monitoring_PDB_PDBStatus_StateBreaker --> 118 b
# 35.141% Extracting bytes of ECC_Monitoring_PDB_PDBStatus_StateEmergencyStop --> 118 b
# 35.341% Extracting bytes of ECC_Monitoring_PDB_PDBStatus_SwitchStatus_General230V --> 118 b
# 35.542% Extracting bytes of ECC_Monitoring_PDB_PDBStatus_SwitchStatus_General400V --> 118 b
# 35.743% Extracting bytes of ECC_Monitoring_PDB_PDBStatus_SwitchStatus_fanFront --> 118 b
# 35.944% Extracting bytes of ECC_Monitoring_PDB_PDBStatus_SwitchStatus_fanRear --> 118 b
# 36.145% Extracting bytes of ECC_Monitoring_PDB_PDBStatus_SwitchStatus_line400V --> 118 b
# 36.345% Extracting bytes of ECC_Monitoring_PDB_PDBStatus_SwitchStatus_shutter --> 118 b
# 36.546% Extracting bytes of ECC_Monitoring_PDB_PDBStatus_SwitchStatus_switch1 --> 118 b
# 36.747% Extracting bytes of ECC_Monitoring_PDB_PDBStatus_SwitchStatus_switch2 --> 118 b
# 36.948% Extracting bytes of ECC_Monitoring_PDB_PDBStatus_TriggerPowerSupply --> 118 b
# 37.149% Extracting bytes of ECC_Monitoring_PDB_PhaseToPhase400VSensors_PhaseToPhase400V_L --> 776 b
# 37.349% Extracting bytes of ECC_Monitoring_PDB_Power_ActivePower400V_L --> 902 b
# 37.550% Extracting bytes of ECC_Monitoring_PDB_Power_ActivePowerUPS --> 189 b
# 37.751% Extracting bytes of ECC_Monitoring_PDB_Power_ApparentPower400V_L --> 1343 b
# 37.952% Extracting bytes of ECC_Monitoring_PDB_Power_ApparentPowerUPS --> 189 b
# 38.153% Extracting bytes of ECC_Monitoring_PDB_Power_PowerFactorUPS --> 253 b
# 38.353% Extracting bytes of ECC_Monitoring_PDB_Power_PowerFactor_L --> 902 b
# 38.554% Extracting bytes of ECC_Monitoring_PDB_Power_ReactiveCapacitivePowerUPS --> 381 b
# 38.755% Extracting bytes of ECC_Monitoring_PDB_Power_ReactiveInductivePowerUPS --> 125 b
# 38.956% Extracting bytes of ECC_Monitoring_PDB_Power_ReactivePower400V_L --> 902 b
# 39.157% Extracting bytes of ECC_Monitoring_PDB_Power_ReactivePowerUPS --> 381 b
# 39.357% Extracting bytes of ECC_Monitoring_PDB_Temperature --> 125 b
# 39.558% Extracting bytes of ECC_Monitoring_PDB_VoltageSensors_VoltageSupply230V --> 317 b
# 39.759% Extracting bytes of ECC_Monitoring_PDB_VoltageSensors_VoltageSupply400V_L --> 1280 b
# 39.960% Extracting bytes of ECC_Monitoring_PSB_CurrentSupply24VPSB --> 144 b
# 40.161% Extracting bytes of ECC_Monitoring_PSB_PowerSupplyPSB1_ --> 150 b
# 40.361% Extracting bytes of ECC_Monitoring_PSB_PowerSupplyPSB2_ --> 150 b
# 40.562% Extracting bytes of ECC_Monitoring_Rear_fans_GeneralStatus --> 150 b
# 40.763% Extracting bytes of ECC_Monitoring_Sensors_AirDifferentialPressureSensors_AirDifferentialPressureSensor --> 125 b
# 40.964% Extracting bytes of ECC_Monitoring_Sensors_AirDifferentialPressureSensors_AirDifferentialPresureSensor --> 125 b
# 41.165% Extracting bytes of ECC_Monitoring_Sensors_Doors_BackDoorsOpen --> 118 b
# 41.365% Extracting bytes of ECC_Monitoring_Sensors_Doors_BackDoorsSensor --> 136 b
# 41.566% Extracting bytes of ECC_Monitoring_Sensors_Doors_FrontDoorsOpen --> 118 b
# 41.767% Extracting bytes of ECC_Monitoring_Sensors_Flowmeters_FlowmeterSensor --> 125 b
# 41.968% Extracting bytes of ECC_Monitoring_Sensors_HumiditySensors_HumiditySensor --> 125 b
# 42.169% Extracting bytes of ECC_Monitoring_Sensors_HumiditySensors_TempSensor --> 125 b
# 42.369% Extracting bytes of ECC_Monitoring_Sensors_LightSensors_Light_ --> 166 b
# 42.570% Extracting bytes of ECC_Monitoring_Sensors_SmokeSensors_SmokeSensor --> 118 b
# 42.771% Extracting bytes of ECC_Monitoring_Sensors_TemperatureSensors_TemperatureSensor_ --> 4111 b
# 42.972% Extracting bytes of ECC_Monitoring_Sensors_WaterLeakSensors_WaterLeakSensor --> 118 b
# 43.173% Extracting bytes of ECC_Monitoring_Sensors_WaterPressureSensors_WaterPressureSensor_ --> 552 b
# 43.373% Extracting bytes of ECC_Monitoring_Sensors_WaterPressureSensors_WaterPresureSensor_ --> 552 b
# 43.574% Extracting bytes of ECC_Monitoring_Shutter_Down_Contactor --> 136 b
# 43.775% Extracting bytes of ECC_Monitoring_Shutter_Error --> 121 b
# 43.976% Extracting bytes of ECC_Monitoring_Shutter_ErrorInfo --> 122 b
# 44.177% Extracting bytes of ECC_Monitoring_Shutter_GeneralStatus --> 121 b
# 44.378% Extracting bytes of ECC_Monitoring_Shutter_KeyStatus --> 118 b
# 44.578% Extracting bytes of ECC_Monitoring_Shutter_PLC_Shutter_PLC_AngularSensor --> 125 b
# 44.779% Extracting bytes of ECC_Monitoring_Shutter_PLC_Shutter_PLC_CloseButton --> 118 b
# 44.980% Extracting bytes of ECC_Monitoring_Shutter_PLC_Shutter_PLC_CommunicationStatus --> 121 b
# 45.181% Extracting bytes of ECC_Monitoring_Shutter_PLC_Shutter_PLC_EmergencyButton --> 118 b
# 45.382% Extracting bytes of ECC_Monitoring_Shutter_PLC_Shutter_PLC_ErrorType --> 121 b
# 45.582% Extracting bytes of ECC_Monitoring_Shutter_PLC_Shutter_PLC_OpenButton --> 118 b
# 45.783% Extracting bytes of ECC_Monitoring_Shutter_PLC_Shutter_PLC_Reserved --> 121 b
# 45.984% Extracting bytes of ECC_Monitoring_Shutter_PLC_Shutter_PLC_SelectAutoManual --> 118 b
# 46.185% Extracting bytes of ECC_Monitoring_Shutter_PLC_Shutter_PLC_Status --> 121 b
# 46.386% Extracting bytes of ECC_Monitoring_Shutter_PLC_Shutter_PLC_WireSensor --> 125 b
# 46.586% Extracting bytes of ECC_Monitoring_Shutter_Up_Contactor --> 136 b
# 46.787% Extracting bytes of ECC_Monitoring_Spares_Analog_A0_ --> 256 b
# 46.988% Extracting bytes of ECC_Monitoring_Spares_Analog_AI_ --> 352 b
# 47.189% Extracting bytes of ECC_Monitoring_Spares_Digital_D0_ --> 171 b
# 47.390% Extracting bytes of ECC_Monitoring_Spares_Digital_DI_ --> 344 b
# 47.590% Extracting bytes of ECC_Monitoring_Spares_Heater --> 136 b
# 47.791% Extracting bytes of ECC_Monitoring_Transition_Countdown --> 121 b
# 47.992% Extracting bytes of ECC_Monitoring_Transition_Information --> 136 b
# 48.193% Extracting bytes of ECC_Monitoring_WhiteTarget_Horizontal_BottomLeft --> 136 b
# 48.394% Extracting bytes of ECC_Monitoring_WhiteTarget_Horizontal_BottomRight --> 136 b
# 48.594% Extracting bytes of ECC_Monitoring_WhiteTarget_Horizontal_HorizontalEncoder --> 136 b
# 48.795% Extracting bytes of ECC_Monitoring_WhiteTarget_Horizontal_TopLeft --> 136 b
# 48.996% Extracting bytes of ECC_Monitoring_WhiteTarget_Horizontal_TopRight --> 136 b
# 49.197% Extracting bytes of ECC_Monitoring_WhiteTarget_Vertical_Bottom --> 136 b
# 49.398% Extracting bytes of ECC_Monitoring_WhiteTarget_Vertical_Top --> 136 b
# 49.598% Extracting bytes of ECC_Monitoring_WhiteTarget_Vertical_VerticalEncoder --> 136 b
# 49.799% Extracting bytes of ECC__ControlLoopTimeStamp --> 136 b
# 50.000% Extracting bytes of TIB_Alarm_AlarmVector --> 121 b
# 50.201% Extracting bytes of TIB_Alarm_AlmostFull --> 118 b
# 50.402% Extracting bytes of TIB_Alarm_BufferFull --> 118 b
# 50.602% Extracting bytes of TIB_Alarm_PPSFailure --> 118 b
# 50.803% Extracting bytes of TIB_Alarm_ReadError --> 118 b
# 51.004% Extracting bytes of TIB_Alarm_Unlocked --> 118 b
# 51.205% Extracting bytes of TIB_Alarm_WriteError --> 118 b
# 51.406% Extracting bytes of TIB_ArmedDelayStereo --> 118 b
# 51.606% Extracting bytes of TIB_BUSY_BusyBP --> 118 b
# 51.807% Extracting bytes of TIB_BUSY_DisableBusy --> 118 b
# 52.008% Extracting bytes of TIB_BUSY_ExtraDelayBusy --> 118 b
# 52.209% Extracting bytes of TIB_BUSY_InternalBusy --> 118 b
# 52.410% Extracting bytes of TIB_Clock_select --> 118 b
# 52.610% Extracting bytes of TIB_CoincidenceWindow --> 125 b
# 52.811% Extracting bytes of TIB_ConnectionStatus --> 118 b
# 53.012% Extracting bytes of TIB_DACOptical_Neighbour --> 188 b
# 53.213% Extracting bytes of TIB_DebugVector --> 121 b
# 53.414% Extracting bytes of TIB_Delays_CompoundDelay --> 121 b
# 53.614% Extracting bytes of TIB_Delays_Delay --> 166 b
# 53.815% Extracting bytes of TIB_Delays_DelayLocal --> 125 b
# 54.016% Extracting bytes of TIB_EventsInRun_BUSYRun --> 125 b
# 54.217% Extracting bytes of TIB_EventsInRun_CalibrationRun --> 125 b
# 54.418% Extracting bytes of TIB_EventsInRun_CameraRun --> 125 b
# 54.618% Extracting bytes of TIB_EventsInRun_CollectedRun --> 125 b
# 54.819% Extracting bytes of TIB_EventsInRun_In1Run --> 125 b
# 55.020% Extracting bytes of TIB_EventsInRun_In2Run --> 125 b
# 55.221% Extracting bytes of TIB_EventsInRun_In3Run --> 125 b
# 55.422% Extracting bytes of TIB_EventsInRun_In4Run --> 125 b
# 55.622% Extracting bytes of TIB_EventsInRun_LocalRun --> 125 b
# 55.823% Extracting bytes of TIB_EventsInRun_PPSRun --> 125 b
# 56.024% Extracting bytes of TIB_EventsInRun_PedestalRun --> 125 b
# 56.225% Extracting bytes of TIB_EventsInRun_SlowControlRun --> 125 b
# 56.426% Extracting bytes of TIB_EventsInRun_SoftrigRun --> 125 b
# 56.627% Extracting bytes of TIB_EventsInRun_SpheRun --> 125 b
# 56.827% Extracting bytes of TIB_EventsInRun_StereoRun --> 125 b
# 57.028% Extracting bytes of TIB_ExternalDelay_ExternalDelayCalibration --> 125 b
# 57.229% Extracting bytes of TIB_ExternalDelay_ExternalDelayLocal --> 125 b
# 57.430% Extracting bytes of TIB_ExternalDelay_ExternalDelaySphe --> 125 b
# 57.631% Extracting bytes of TIB_InputsEnable_Input --> 150 b
# 57.831% Extracting bytes of TIB_InputsEnable_InputLocal --> 118 b
# 58.032% Extracting bytes of TIB_InputsEnable_InputMask --> 121 b
# 58.233% Extracting bytes of TIB_OF_delayMeasure_Launch_OF_measure --> 121 b
# 58.434% Extracting bytes of TIB_OF_delayMeasure_OF_delay --> 121 b
# 58.635% Extracting bytes of TIB_OF_delayMeasure_Passive_OF_resend --> 121 b
# 58.835% Extracting bytes of TIB_Pedestal_AnalogPedestalEnable --> 118 b
# 59.036% Extracting bytes of TIB_Pedestal_AnalogPedestalThreshold --> 125 b
# 59.237% Extracting bytes of TIB_Pedestal_DigitalPedestalEnable --> 118 b
# 59.438% Extracting bytes of TIB_Pedestal_DigitalPedestalSeed --> 118 b
# 59.639% Extracting bytes of TIB_Pedestal_DigitalPedestal_config_Rate --> 121 b
# 59.839% Extracting bytes of TIB_Pedestal_Fake_trig_enable --> 118 b
# 60.040% Extracting bytes of TIB_Pedestal_PeriodicPedestalEnable --> 118 b
# 60.241% Extracting bytes of TIB_Pedestal_PeriodicPedestalFrequency --> 121 b
# 60.442% Extracting bytes of TIB_Rates_BUSYRate --> 125 b
# 60.643% Extracting bytes of TIB_Rates_CalibrationRate --> 125 b
# 60.843% Extracting bytes of TIB_Rates_CameraRate --> 125 b
# 61.044% Extracting bytes of TIB_Rates_CollectedRate --> 125 b
# 61.245% Extracting bytes of TIB_Rates_In1Rate --> 125 b
# 61.446% Extracting bytes of TIB_Rates_In2Rate --> 125 b
# 61.647% Extracting bytes of TIB_Rates_In3Rate --> 125 b
# 61.847% Extracting bytes of TIB_Rates_In4Rate --> 125 b
# 62.048% Extracting bytes of TIB_Rates_In5Rate --> 125 b
# 62.249% Extracting bytes of TIB_Rates_In6Rate --> 125 b
# 62.450% Extracting bytes of TIB_Rates_In7Rate --> 125 b
# 62.651% Extracting bytes of TIB_Rates_In8Rate --> 125 b
# 62.851% Extracting bytes of TIB_Rates_LocalRate --> 125 b
# 63.052% Extracting bytes of TIB_Rates_PedestalRate --> 125 b
# 63.253% Extracting bytes of TIB_Rates_SoftrigRate --> 125 b
# 63.454% Extracting bytes of TIB_Rates_SpheRate --> 221 b
# 63.655% Extracting bytes of TIB_Rates_StereoRate --> 125 b
# 63.855% Extracting bytes of TIB_ReadState --> 121 b
# 64.056% Extracting bytes of TIB_RedundantCables_RedundantCable --> 136 b
# 64.257% Extracting bytes of TIB_StereoCondition --> 136 b
# 64.458% Extracting bytes of TIB_TIB_TXclient_alive --> 118 b
# 64.659% Extracting bytes of TIB_Temperature --> 221 b
# 64.859% Extracting bytes of TIB_Throttler_DisableThrottler --> 118 b
# 65.060% Extracting bytes of TIB_Throttler_MaxTriggers1ms --> 121 b
# 65.261% Extracting bytes of TIB_Throttler_MaxTriggers50us --> 121 b
# 65.462% Extracting bytes of TIB_TriggerMode_CalibrationEnable --> 118 b
# 65.663% Extracting bytes of TIB_TriggerMode_ModeMask --> 121 b
# 65.863% Extracting bytes of TIB_TriggerMode_MonoEnable --> 118 b
# 66.064% Extracting bytes of TIB_TriggerMode_PedestalEnable --> 118 b
# 66.265% Extracting bytes of TIB_TriggerMode_SlowControlEnable --> 118 b
# 66.466% Extracting bytes of TIB_TriggerMode_SoftwareTrigEnable --> 118 b
# 66.667% Extracting bytes of TIB_TriggerMode_SpheEnable --> 118 b
# 66.867% Extracting bytes of TIB_TriggerMode_StereoEnable --> 118 b
# 67.068% Extracting bytes of TIB__ControlLoopTimeStamp --> 118 b
# 67.269% Extracting bytes of exports_FSM_error_error_message --> 118 b
# 67.470% Extracting bytes of exports_FSM_state --> 149 b
# 67.671% Extracting bytes of exports__ControlLoopTimeStamp --> 149 b
# 67.871% Extracting bytes of exports_actions_calibrations_external_delay_end_time --> 149 b
# 68.072% Extracting bytes of exports_actions_calibrations_external_delay_start_time --> 149 b
# 68.273% Extracting bytes of exports_actions_calibrations_external_delay_status --> 121 b
# 68.474% Extracting bytes of exports_actions_calibrations_external_delay_values --> 32402 b
# 68.675% Extracting bytes of exports_actions_calibrations_external_delay_xtra_information --> 124 b
# 68.876% Extracting bytes of exports_actions_calibrations_external_gain_end_time --> 124 b
# 69.076% Extracting bytes of exports_actions_calibrations_external_gain_start_time --> 124 b
# 69.277% Extracting bytes of exports_actions_calibrations_external_gain_status --> 121 b
# 69.478% Extracting bytes of exports_actions_calibrations_external_gain_values --> 9612 b
# 69.679% Extracting bytes of exports_actions_calibrations_external_gain_xtra_information --> 124 b
# 69.880% Extracting bytes of exports_actions_calibrations_internal_delay_end_time --> 124 b
# 70.080% Extracting bytes of exports_actions_calibrations_internal_delay_start_time --> 124 b
# 70.281% Extracting bytes of exports_actions_calibrations_internal_delay_status --> 121 b
# 70.482% Extracting bytes of exports_actions_calibrations_internal_delay_values --> 24982 b
# 70.683% Extracting bytes of exports_actions_calibrations_internal_delay_xtra_information --> 124 b
# 70.884% Extracting bytes of exports_actions_calibrations_internal_gain_end_time --> 124 b
# 71.084% Extracting bytes of exports_actions_calibrations_internal_gain_start_time --> 124 b
# 71.285% Extracting bytes of exports_actions_calibrations_internal_gain_status --> 121 b
# 71.486% Extracting bytes of exports_actions_calibrations_internal_gain_values --> 17562 b
# 71.687% Extracting bytes of exports_actions_calibrations_internal_gain_xtra_information --> 124 b
# 71.888% Extracting bytes of exports_actions_calibrations_pixel_DTN0 --> 124 b
# 72.088% Extracting bytes of exports_actions_calibrations_pixel_DTl0 --> 124 b
# 72.289% Extracting bytes of exports_actions_calibrations_pixels_DTL0 --> 17562 b
# 72.490% Extracting bytes of exports_actions_calibrations_pixels_DTN --> 36112 b
# 72.691% Extracting bytes of exports_actions_scans_scan_ipr_begin --> 121 b
# 72.892% Extracting bytes of exports_actions_scans_scan_ipr_end --> 121 b
# 73.092% Extracting bytes of exports_actions_scans_scan_ipr_end_time --> 121 b
# 73.293% Extracting bytes of exports_actions_scans_scan_ipr_start_time --> 121 b
# 73.494% Extracting bytes of exports_actions_scans_scan_ipr_status --> 121 b
# 73.695% Extracting bytes of exports_actions_scans_scan_ipr_steps --> 121 b
# 73.896% Extracting bytes of exports_actions_scans_scan_ipr_values_values --> 121 b
# 74.096% Extracting bytes of exports_actions_scans_scan_l1_begin --> 121 b
# 74.297% Extracting bytes of exports_actions_scans_scan_l1_end --> 121 b
# 74.498% Extracting bytes of exports_actions_scans_scan_l1_end_time --> 121 b
# 74.699% Extracting bytes of exports_actions_scans_scan_l1_start_time --> 121 b
# 74.900% Extracting bytes of exports_actions_scans_scan_l1_status --> 121 b
# 75.100% Extracting bytes of exports_actions_scans_scan_l1_steps --> 121 b
# 75.301% Extracting bytes of exports_actions_scans_scan_l1_values_values --> 121 b
# 75.502% Extracting bytes of exports_monitoring_clusco_busy_state --> 149 b
# 75.703% Extracting bytes of exports_monitoring_clusco_central_bp --> 149 b
# 75.904% Extracting bytes of exports_monitoring_clusco_date_built --> 133 b
# 76.104% Extracting bytes of exports_monitoring_clusco_error --> 133 b
# 76.305% Extracting bytes of exports_monitoring_clusco_hv_on --> 118 b
# 76.506% Extracting bytes of exports_monitoring_clusco_l0_hot --> 121 b
# 76.707% Extracting bytes of exports_monitoring_clusco_l0_rate_control --> 118 b
# 76.908% Extracting bytes of exports_monitoring_clusco_l0_rate_max --> 121 b
# 77.108% Extracting bytes of exports_monitoring_clusco_l1_rate_control --> 118 b
# 77.309% Extracting bytes of exports_monitoring_clusco_l1_rate_max --> 121 b
# 77.510% Extracting bytes of exports_monitoring_clusco_l1_rate_target --> 121 b
# 77.711% Extracting bytes of exports_monitoring_clusco_last_report_msecond --> 121 b
# 77.912% Extracting bytes of exports_monitoring_clusco_last_report_second --> 125 b
# 78.112% Extracting bytes of exports_monitoring_clusco_major_ver --> 125 b
# 78.313% Extracting bytes of exports_monitoring_clusco_major_version --> 125 b
# 78.514% Extracting bytes of exports_monitoring_clusco_mean_dc --> 157 b
# 78.715% Extracting bytes of exports_monitoring_clusco_mean_dc_healthy --> 125 b
# 78.916% Extracting bytes of exports_monitoring_clusco_minor_ver --> 125 b
# 79.116% Extracting bytes of exports_monitoring_clusco_minor_version --> 125 b
# 79.317% Extracting bytes of exports_monitoring_clusco_monitoring_sleep --> 125 b
# 79.518% Extracting bytes of exports_monitoring_clusco_nb_hv_reduced --> 125 b
# 79.719% Extracting bytes of exports_monitoring_clusco_read_once_msecond --> 121 b
# 79.920% Extracting bytes of exports_monitoring_clusco_read_once_second --> 121 b
# 80.120% Extracting bytes of exports_monitoring_clusco_read_rarely_msecond --> 121 b
# 80.321% Extracting bytes of exports_monitoring_clusco_read_rarely_second --> 121 b
# 80.522% Extracting bytes of exports_monitoring_clusco_sub_ver --> 121 b
# 80.723% Extracting bytes of exports_monitoring_clusco_sub_version --> 121 b
# 80.924% Extracting bytes of exports_monitoring_clusco_time_built --> 130 b
# 81.124% Extracting bytes of exports_monitoring_clusco_zenith --> 125 b
# 81.325% Extracting bytes of exports_monitoring_hardware_values_cluster_backplane_firmware --> 125 b
# 81.526% Extracting bytes of exports_monitoring_hardware_values_cluster_backplane_flag --> 125 b
# 81.727% Extracting bytes of exports_monitoring_hardware_values_cluster_backplane_reg65 --> 125 b
# 81.928% Extracting bytes of exports_monitoring_hardware_values_cluster_backplane_scalar --> 125 b
# 82.129% Extracting bytes of exports_monitoring_hardware_values_cluster_backplane_tdc_delta --> 125 b
# 82.329% Extracting bytes of exports_monitoring_hardware_values_cluster_backplane_temperature --> 125 b
# 82.530% Extracting bytes of exports_monitoring_hardware_values_cluster_bp_scalar --> 125 b
# 82.731% Extracting bytes of exports_monitoring_hardware_values_cluster_bp_tdc_delta --> 125 b
# 82.932% Extracting bytes of exports_monitoring_hardware_values_cluster_bp_temperature --> 125 b
# 83.133% Extracting bytes of exports_monitoring_hardware_values_cluster_busy --> 125 b
# 83.333% Extracting bytes of exports_monitoring_hardware_values_cluster_dragon_busy --> 4701 b
# 83.534% Extracting bytes of exports_monitoring_hardware_values_cluster_dragon_drs4_humidity --> 3457 b
# 83.735% Extracting bytes of exports_monitoring_hardware_values_cluster_dragon_drs4_temperature --> 3457 b
# 83.936% Extracting bytes of exports_monitoring_hardware_values_cluster_dragon_drs_cascade_channels --> 3457 b
# 84.137% Extracting bytes of exports_monitoring_hardware_values_cluster_dragon_drs_mode --> 2397 b
# 84.337% Extracting bytes of exports_monitoring_hardware_values_cluster_dragon_drs_offset --> 2397 b
# 84.538% Extracting bytes of exports_monitoring_hardware_values_cluster_dragon_drs_read_depth --> 2397 b
# 84.739% Extracting bytes of exports_monitoring_hardware_values_cluster_dragon_drs_sampling_frequency --> 2397 b
# 84.940% Extracting bytes of exports_monitoring_hardware_values_cluster_dragon_drs_trigger_delay --> 2397 b
# 85.141% Extracting bytes of exports_monitoring_hardware_values_cluster_dragon_drs_trigger_selection --> 2397 b
# 85.341% Extracting bytes of exports_monitoring_hardware_values_cluster_dragon_firmware --> 2397 b
# 85.542% Extracting bytes of exports_monitoring_hardware_values_cluster_dragon_flag --> 2397 b
# 85.743% Extracting bytes of exports_monitoring_hardware_values_cluster_dragon_l0_rate_window --> 2397 b
# 85.944% Extracting bytes of exports_monitoring_hardware_values_cluster_dragon_l1_rate_window --> 2397 b
# 86.145% Extracting bytes of exports_monitoring_hardware_values_cluster_dragon_mac_address --> 2397 b
# 86.345% Extracting bytes of exports_monitoring_hardware_values_cluster_dragon_reg_temperature --> 2397 b
# 86.546% Extracting bytes of exports_monitoring_hardware_values_cluster_dragon_six_v --> 3457 b
# 86.747% Extracting bytes of exports_monitoring_hardware_values_cluster_dragon_tp_injection --> 2397 b
# 86.948% Extracting bytes of exports_monitoring_hardware_values_cluster_dragon_tp_rate --> 2397 b
# 87.149% Extracting bytes of exports_monitoring_hardware_values_cluster_enabled --> 2397 b
# 87.349% Extracting bytes of exports_monitoring_hardware_values_cluster_error --> 2397 b
# 87.550% Extracting bytes of exports_monitoring_hardware_values_cluster_l0_majority --> 2397 b
# 87.751% Extracting bytes of exports_monitoring_hardware_values_cluster_l0_sate --> 2397 b
# 87.952% Extracting bytes of exports_monitoring_hardware_values_cluster_l0_sum --> 2397 b
# 88.153% Extracting bytes of exports_monitoring_hardware_values_cluster_l1_adder --> 7167 b
# 88.353% Extracting bytes of exports_monitoring_hardware_values_cluster_l1_dac_threshold_default --> 7167 b
# 88.554% Extracting bytes of exports_monitoring_hardware_values_cluster_l1_dac_threshold_set --> 7167 b
# 88.755% Extracting bytes of exports_monitoring_hardware_values_cluster_l1_extern_rate --> 2397 b
# 88.956% Extracting bytes of exports_monitoring_hardware_values_cluster_l1_rate --> 2397 b
# 89.157% Extracting bytes of exports_monitoring_hardware_values_cluster_l1_rate_low --> 2397 b
# 89.357% Extracting bytes of exports_monitoring_hardware_values_cluster_l1_state --> 2397 b
# 89.558% Extracting bytes of exports_monitoring_hardware_values_cluster_majority_enabled --> 2397 b
# 89.759% Extracting bytes of exports_monitoring_hardware_values_cluster_number --> 2397 b
# 89.960% Extracting bytes of exports_monitoring_hardware_values_cluster_port --> 2397 b
# 90.161% Extracting bytes of exports_monitoring_hardware_values_cluster_scb_flag --> 2397 b
# 90.361% Extracting bytes of exports_monitoring_hardware_values_cluster_scb_humidity --> 10185 b
# 90.562% Extracting bytes of exports_monitoring_hardware_values_cluster_scb_hw_version --> 10185 b
# 90.763% Extracting bytes of exports_monitoring_hardware_values_cluster_scb_id_code --> 10185 b
# 90.964% Extracting bytes of exports_monitoring_hardware_values_cluster_scb_pmask --> 2397 b
# 91.165% Extracting bytes of exports_monitoring_hardware_values_cluster_scb_pmt_current --> 2397 b
# 91.365% Extracting bytes of exports_monitoring_hardware_values_cluster_scb_sw_version --> 2397 b
# 91.566% Extracting bytes of exports_monitoring_hardware_values_cluster_scb_temperature --> 6821 b
# 91.767% Extracting bytes of exports_monitoring_hardware_values_cluster_scb_testpulse_enabled --> 2397 b
# 91.968% Extracting bytes of exports_monitoring_hardware_values_cluster_scb_uid --> 2397 b
# 92.169% Extracting bytes of exports_monitoring_hardware_values_cluster_state --> 2397 b
# 92.369% Extracting bytes of exports_monitoring_hardware_values_cluster_sum_enabled --> 2397 b
# 92.570% Extracting bytes of exports_monitoring_hardware_values_cluster_sw_version --> 2397 b
# 92.771% Extracting bytes of exports_monitoring_hardware_values_cluster_tp_rate --> 2397 b
# 92.972% Extracting bytes of exports_monitoring_hardware_values_pixel_AN_current --> 2397 b
# 93.173% Extracting bytes of exports_monitoring_hardware_values_pixel_clipping_bias --> 2397 b
# 93.373% Extracting bytes of exports_monitoring_hardware_values_pixel_clipping_sel --> 2397 b
# 93.574% Extracting bytes of exports_monitoring_hardware_values_pixel_delay --> 2397 b
# 93.775% Extracting bytes of exports_monitoring_hardware_values_pixel_dt --> 2397 b
# 93.976% Extracting bytes of exports_monitoring_hardware_values_pixel_enabled --> 17562 b
# 94.177% Extracting bytes of exports_monitoring_hardware_values_pixel_error --> 17562 b
# 94.378% Extracting bytes of exports_monitoring_hardware_values_pixel_gain --> 17562 b
# 94.578% Extracting bytes of exports_monitoring_hardware_values_pixel_l0_asic_main_register --> 69969 b
# 94.779% Extracting bytes of exports_monitoring_hardware_values_pixel_l0_clipping_bias --> 17562 b
# 94.980% Extracting bytes of exports_monitoring_hardware_values_pixel_l0_clipping_sel --> 17562 b
# 95.181% Extracting bytes of exports_monitoring_hardware_values_pixel_l0_delay --> 24982 b
# 95.382% Extracting bytes of exports_monitoring_hardware_values_pixel_l0_dt --> 17562 b
# 95.582% Extracting bytes of exports_monitoring_hardware_values_pixel_l0_gain --> 17562 b
# 95.783% Extracting bytes of exports_monitoring_hardware_values_pixel_l0_ipr --> 69969 b
# 95.984% Extracting bytes of exports_monitoring_hardware_values_pixel_l0_on --> 17562 b
# 96.185% Extracting bytes of exports_monitoring_hardware_values_pixel_l0_rate --> 17562 b
# 96.386% Extracting bytes of exports_monitoring_hardware_values_pixel_l0_threshold_register --> 17562 b
# 96.586% Extracting bytes of exports_monitoring_hardware_values_pixel_pixel_error --> 17562 b
# 96.787% Extracting bytes of exports_monitoring_hardware_values_pixel_scb_amplifier_id_code --> 17562 b
# 96.988% Extracting bytes of exports_monitoring_hardware_values_pixel_scb_an_current --> 99649 b
# 97.189% Extracting bytes of exports_monitoring_hardware_values_pixel_scb_hotcold --> 35031 b
# 97.390% Extracting bytes of exports_monitoring_hardware_values_pixel_scb_hv_default --> 24982 b
# 97.590% Extracting bytes of exports_monitoring_hardware_values_pixel_scb_hv_monitored --> 99649 b
# 97.791% Extracting bytes of exports_monitoring_hardware_values_pixel_scb_hv_set --> 24982 b
# 97.992% Extracting bytes of exports_monitoring_hardware_values_pixel_scb_pcode --> 17562 b
# 98.193% Extracting bytes of exports_monitoring_hardware_values_pixel_scb_pixel_temperature --> 17562 b
# 98.394% Extracting bytes of exports_monitoring_hardware_values_pixel_scb_temperature --> 24982 b
# 98.594% Extracting bytes of exports_monitoring_hardware_values_pixel_scb_tp_boost --> 17562 b
# 98.795% Extracting bytes of exports_monitoring_hardware_values_pixel_scb_tp_gain --> 17562 b
# 98.996% Extracting bytes of exports_monitoring_hardware_values_pixel_tp_boost --> 17562 b
# 99.197% Extracting bytes of exports_monitoring_number_of_cluster --> 17562 b
# 99.398% Extracting bytes of exports_monitoring_number_of_clusters --> 17562 b
# 99.598% Extracting bytes of exports_monitoring_state --> 17562 b
# 99.799% Extracting bytes of exports_monitoring_version --> 127 b

# %% [markdown]
# #### Getting the number of entries for each state and timespan, so then the bytes

# %%
# %%time
# Creating a dictionary to store the information
event_dict = {}
for key in dict_caco_states.keys():
    event_dict[key] = np.repeat(0, len(timespans_dict[key]["tstart"]))

# Taking the main collections and chunks pointers
property_collection = client_tcu['bridgesmonitoring']['properties']
chunk_collection = client_tcu['bridgesmonitoring']['chunks']


# Iterating for all states
# state = 0

for p, _property in enumerate(camera_related_tcu_properties):
    print(f"Finding data of property {_property}... {p}/{len(camera_related_tcu_properties)}") if p % 1 == 0 else None
    descriptors = property_collection.find({'property_name': _property})

    for desc in descriptors:
        for state in dict_caco_states.keys():
            print(f"Extracting for state {state} : {dict_caco_states[state]}")
            # print(f"The number of timespans is -> {len(timespans_dict[state]['tstart'])}")

            # Then running for all the timespans
            for i in range(len(timespans_dict[state]["tstart"]))[:]:

                _tstart = timespans_dict[state]["tstart"][i]
                _tstop  = timespans_dict[state]["tstop"][i]
                # _center_time = _tstart + (_tstop - _tstart) / 2
                # _timespan = (_tstop - _tstart).total_seconds()

                # print(f"From {_tstart} to {_tstop}, a total of {_timespan:.0f} seconds")
                print(f"Running over timespans... {i}/{len(timespans_dict[state]['tstart'])}") if i% 150 == 0 else None
                
                query = {'pid': desc['_id']}
                query.update({"begin": {"$gte": _tstart}, "end": {"$lte": _tstop}})

                number_chunks = chunk_collection.count_documents(query)

                # event_dict[state]['timestamp'].append(_center_time)
                event_dict[state][i] += number_chunks * dict_tcu_property_bytes[_property]

# # Saving the object
# with open(f"objects/event_dict_state_{state}.pkl", "wb") as f:
#     pickle.dump(event_dict, f, pickle.HIGHEST_PROTOCOL)
    
# # Reading the saved objects
# with open(f"objects/event_dict_state_{state}.pkl", "rb") as f:
#     event_dict = pickle.load(f)
# Out:
# Finding data of property CalibrationBox_BG_InterCalibration_Mean... 0/498
# Extracting for state 0 : OFF
# Running over timespans... 0/27
# Extracting for state 1 : DATA_MONITORING
# Extracting for state 2 : MONITORED
# Extracting for state 3 : SAFE
# Running over timespans... 0/56
# Extracting for state 4 : STANDBY
# Running over timespans... 0/119
# Extracting for state 5 : READY
# Running over timespans... 0/1288
# Running over timespans... 150/1288
# Running over timespans... 300/1288
# Running over timespans... 450/1288
# Running over timespans... 600/1288
# Running over timespans... 750/1288
# Running over timespans... 900/1288
# Running over timespans... 1050/1288
# Running over timespans... 1200/1288
# Extracting for state 6 : OBSERVING
# Running over timespans... 0/508
# Running over timespans... 150/508
# Running over timespans... 300/508
# Running over timespans... 450/508
# Extracting for state 7 : TPOINT
# Running over timespans... 0/34
# Extracting for state 8 : UNDEFINED
# Running over timespans... 0/41
# Extracting for state 9 : TRANSITIONAL
# Running over timespans... 0/2047
# Running over timespans... 150/2047
# Running over timespans... 300/2047
# Running over timespans... 450/2047
# Running over timespans... 600/2047
# Running over timespans... 750/2047
# Running over timespans... 900/2047
# Running over timespans... 1050/2047
# Running over timespans... 1200/2047
# Running over timespans... 1350/2047
# Running over timespans... 1500/2047
# Running over timespans... 1650/2047
# Running over timespans... 1800/2047
# Running over timespans... 1950/2047
# Extracting for state 10 : ERROR
# Finding data of property CalibrationBox_DewPoint... 1/498
# Extracting for state 0 : OFF
# Running over timespans... 0/27
# Extracting for state 1 : DATA_MONITORING
# Extracting for state 2 : MONITORED
# Extracting for state 3 : SAFE
# Running over timespans... 0/56
# Extracting for state 4 : STANDBY
# Running over timespans... 0/119
# Extracting for state 5 : READY
# Running over timespans... 0/1288
# Running over timespans... 150/1288
# Running over timespans... 300/1288
# Running over timespans... 450/1288
# Running over timespans... 600/1288
# Running over timespans... 750/1288
# Running over timespans... 900/1288
# Running over timespans... 1050/1288
# Running over timespans... 1200/1288
# Extracting for state 6 : OBSERVING
# Running over timespans... 0/508
# Running over timespans... 150/508
# Running over timespans... 300/508
# Running over timespans... 450/508
# Extracting for state 7 : TPOINT
# Running over timespans... 0/34
# Extracting for state 8 : UNDEFINED
# Running over timespans... 0/41
# Extracting for state 9 : TRANSITIONAL
# Running over timespans... 0/2047
# Running over timespans... 150/2047
# Running over timespans... 300/2047
# Running over timespans... 450/2047
# Running over timespans... 600/2047
# Running over timespans... 750/2047
# Running over timespans... 900/2047
# Running over timespans... 1050/2047
# Running over timespans... 1200/2047
# Running over timespans... 1350/2047
# Running over timespans... 1500/2047
# Running over timespans... 1650/2047
# Running over timespans... 1800/2047
# Running over timespans... 1950/2047
# Extracting for state 10 : ERROR
# Finding data of property CalibrationBox_Error_BG_InterCalibration_Mean... 2/498
# Extracting for state 0 : OFF
# Running over timespans... 0/27
# Extracting for state 1 : DATA_MONITORING
# Extracting for state 2 : MONITORED
# Extracting for state 3 : SAFE
# Running over timespans... 0/56
# Extracting for state 4 : STANDBY
# Running over timespans... 0/119
# Extracting for state 5 : READY
# Running over timespans... 0/1288
# Running over timespans... 150/1288
# Running over timespans... 300/1288
# Running over timespans... 450/1288
# Running over timespans... 600/1288
# Running over timespans... 750/1288
# Running over timespans... 900/1288
# Running over timespans... 1050/1288
# Running over timespans... 1200/1288
# Extracting for state 6 : OBSERVING
# Running over timespans... 0/508
# Running over timespans... 150/508
# Running over timespans... 300/508
# Running over timespans... 450/508
# Extracting for state 7 : TPOINT
# Running over timespans... 0/34
# Extracting for state 8 : UNDEFINED
# Running over timespans... 0/41
# Extracting for state 9 : TRANSITIONAL
# Running over timespans... 0/2047
# Running over timespans... 150/2047
# Running over timespans... 300/2047
# Running over timespans... 450/2047
# Running over timespans... 600/2047
# Running over timespans... 750/2047
# Running over timespans... 900/2047
# Running over timespans... 1050/2047
# Running over timespans... 1200/2047
# Running over timespans... 1350/2047
# Running over timespans... 1500/2047
# Running over timespans... 1650/2047
# Running over timespans... 1800/2047
# Running over timespans... 1950/2047
# Extracting for state 10 : ERROR
# Finding data of property CalibrationBox_Error_InterCalibration_Mean... 3/498
# Extracting for state 0 : OFF
# Running over timespans... 0/27
# Extracting for state 1 : DATA_MONITORING
# Extracting for state 2 : MONITORED
# Extracting for state 3 : SAFE
# Running over timespans... 0/56
# Extracting for state 4 : STANDBY
# Running over timespans... 0/119
# Extracting for state 5 : READY
# Running over timespans... 0/1288
# Running over timespans... 150/1288
# Running over timespans... 300/1288
# Running over timespans... 450/1288
# Running over timespans... 600/1288
# Running over timespans... 750/1288
# Running over timespans... 900/1288
# Running over timespans... 1050/1288
# Running over timespans... 1200/1288
# Extracting for state 6 : OBSERVING
# Running over timespans... 0/508
# Running over timespans... 150/508
# Running over timespans... 300/508
# Running over timespans... 450/508
# Extracting for state 7 : TPOINT
# Running over timespans... 0/34
# Extracting for state 8 : UNDEFINED
# Running over timespans... 0/41
# Extracting for state 9 : TRANSITIONAL
# Running over timespans... 0/2047
# Running over timespans... 150/2047
# Running over timespans... 300/2047
# Running over timespans... 450/2047
# Running over timespans... 600/2047
# Running over timespans... 750/2047
# Running over timespans... 900/2047
# Running over timespans... 1050/2047
# Running over timespans... 1200/2047
# Running over timespans... 1350/2047
# Running over timespans... 1500/2047
# Running over timespans... 1650/2047
# Running over timespans... 1800/2047
# Running over timespans... 1950/2047
# Extracting for state 10 : ERROR
# Finding data of property CalibrationBox_FSM_state... 4/498
# Extracting for state 0 : OFF
# Running over timespans... 0/27
# Extracting for state 1 : DATA_MONITORING
# Extracting for state 2 : MONITORED
# Extracting for state 3 : SAFE
# Running over timespans... 0/56
# Extracting for state 4 : STANDBY
# Running over timespans... 0/119
# Extracting for state 5 : READY
# Running over timespans... 0/1288
# Running over timespans... 150/1288
# Running over timespans... 300/1288
# Running over timespans... 450/1288
# Running over timespans... 600/1288
# Running over timespans... 750/1288
# Running over timespans... 900/1288
# Running over timespans... 1050/1288
# Running over timespans... 1200/1288
# Extracting for state 6 : OBSERVING
# Running over timespans... 0/508
# Running over timespans... 150/508
# Running over timespans... 300/508
# Running over timespans... 450/508
# Extracting for state 7 : TPOINT
# Running over timespans... 0/34
# Extracting for state 8 : UNDEFINED
# Running over timespans... 0/41
# Extracting for state 9 : TRANSITIONAL
# Running over timespans... 0/2047
# Running over timespans... 150/2047
# Running over timespans... 300/2047
# Running over timespans... 450/2047
# Running over timespans... 600/2047
# Running over timespans... 750/2047
# Running over timespans... 900/2047
# Running over timespans... 1050/2047
# Running over timespans... 1200/2047
# Running over timespans... 1350/2047
# Running over timespans... 1500/2047
# Running over timespans... 1650/2047
# Running over timespans... 1800/2047
# Running over timespans... 1950/2047
# Extracting for state 10 : ERROR
# Finding data of property CalibrationBox_FSM_transition... 5/498
# Extracting for state 0 : OFF
# Running over timespans... 0/27
# Extracting for state 1 : DATA_MONITORING
# Extracting for state 2 : MONITORED
# Extracting for state 3 : SAFE
# Running over timespans... 0/56
# Extracting for state 4 : STANDBY
# Running over timespans... 0/119
# Extracting for state 5 : READY
# Running over timespans... 0/1288
# Running over timespans... 150/1288
# Running over timespans... 300/1288
# Running over timespans... 450/1288
# Running over timespans... 600/1288
# Running over timespans... 750/1288
# Running over timespans... 900/1288
# Running over timespans... 1050/1288
# Running over timespans... 1200/1288
# Extracting for state 6 : OBSERVING
# Running over timespans... 0/508
# Running over timespans... 150/508
# Running over timespans... 300/508
# Running over timespans... 450/508
# Extracting for state 7 : TPOINT
# Running over timespans... 0/34
# Extracting for state 8 : UNDEFINED
# Running over timespans... 0/41
# Extracting for state 9 : TRANSITIONAL
# Running over timespans... 0/2047
# Running over timespans... 150/2047
# Running over timespans... 300/2047
# Running over timespans... 450/2047
# Running over timespans... 600/2047
# Running over timespans... 750/2047
# Running over timespans... 900/2047
# Running over timespans... 1050/2047
# Running over timespans... 1200/2047
# Running over timespans... 1350/2047
# Running over timespans... 1500/2047
# Running over timespans... 1650/2047
# Running over timespans... 1800/2047
# Running over timespans... 1950/2047
# Extracting for state 10 : ERROR
# Finding data of property CalibrationBox_Humidity... 6/498
# Extracting for state 0 : OFF
# Running over timespans... 0/27
# Extracting for state 1 : DATA_MONITORING
# Extracting for state 2 : MONITORED
# Extracting for state 3 : SAFE
# Running over timespans... 0/56
# Extracting for state 4 : STANDBY
# Running over timespans... 0/119
# Extracting for state 5 : READY
# Running over timespans... 0/1288
# Running over timespans... 150/1288
# Running over timespans... 300/1288
# Running over timespans... 450/1288
# Running over timespans... 600/1288
# Running over timespans... 750/1288
# Running over timespans... 900/1288
# Running over timespans... 1050/1288
# Running over timespans... 1200/1288
# Extracting for state 6 : OBSERVING
# Running over timespans... 0/508
# Running over timespans... 150/508
# Running over timespans... 300/508
# Running over timespans... 450/508
# Extracting for state 7 : TPOINT
# Running over timespans... 0/34
# Extracting for state 8 : UNDEFINED
# Running over timespans... 0/41
# Extracting for state 9 : TRANSITIONAL
# Running over timespans... 0/2047
# Running over timespans... 150/2047
# Running over timespans... 300/2047
# Running over timespans... 450/2047
# Running over timespans... 600/2047
# Running over timespans... 750/2047
# Running over timespans... 900/2047
# Running over timespans... 1050/2047
# Running over timespans... 1200/2047
# Running over timespans... 1350/2047
# Running over timespans... 1500/2047
# Running over timespans... 1650/2047
# Running over timespans... 1800/2047
# Running over timespans... 1950/2047
# Extracting for state 10 : ERROR
# Finding data of property CalibrationBox_InterCalibration_Mean... 7/498
# Extracting for state 0 : OFF
# Running over timespans... 0/27
# Extracting for state 1 : DATA_MONITORING
# Extracting for state 2 : MONITORED
# Extracting for state 3 : SAFE
# Running over timespans... 0/56
# Extracting for state 4 : STANDBY
# Running over timespans... 0/119
# Extracting for state 5 : READY
# Running over timespans... 0/1288
# Running over timespans... 150/1288
# Running over timespans... 300/1288
# Running over timespans... 450/1288
# Running over timespans... 600/1288
# Running over timespans... 750/1288
# Running over timespans... 900/1288
# Running over timespans... 1050/1288
# Running over timespans... 1200/1288
# Extracting for state 6 : OBSERVING
# Running over timespans... 0/508
# Running over timespans... 150/508
# Running over timespans... 300/508
# Running over timespans... 450/508
# Extracting for state 7 : TPOINT
# Running over timespans... 0/34
# Extracting for state 8 : UNDEFINED
# Running over timespans... 0/41
# Extracting for state 9 : TRANSITIONAL
# Running over timespans... 0/2047
# Running over timespans... 150/2047
# Running over timespans... 300/2047
# Running over timespans... 450/2047
# Running over timespans... 600/2047
# Running over timespans... 750/2047
# Running over timespans... 900/2047
# Running over timespans... 1050/2047
# Running over timespans... 1200/2047
# Running over timespans... 1350/2047
# Running over timespans... 1500/2047
# Running over timespans... 1650/2047
# Running over timespans... 1800/2047
# Running over timespans... 1950/2047
# Extracting for state 10 : ERROR
# Finding data of property CalibrationBox_LaserErrorCode... 8/498
# Extracting for state 0 : OFF
# Running over timespans... 0/27
# Extracting for state 1 : DATA_MONITORING
# Extracting for state 2 : MONITORED
# Extracting for state 3 : SAFE
# Running over timespans... 0/56
# Extracting for state 4 : STANDBY
# Running over timespans... 0/119
# Extracting for state 5 : READY
# Running over timespans... 0/1288
# Running over timespans... 150/1288
# Running over timespans... 300/1288
# Running over timespans... 450/1288
# Running over timespans... 600/1288
# Running over timespans... 750/1288
# Running over timespans... 900/1288
# Running over timespans... 1050/1288
# Running over timespans... 1200/1288
# Extracting for state 6 : OBSERVING
# Running over timespans... 0/508
# Running over timespans... 150/508
# Running over timespans... 300/508
# Running over timespans... 450/508
# Extracting for state 7 : TPOINT
# Running over timespans... 0/34
# Extracting for state 8 : UNDEFINED
# Running over timespans... 0/41
# Extracting for state 9 : TRANSITIONAL
# Running over timespans... 0/2047
# Running over timespans... 150/2047
# Running over timespans... 300/2047
# Running over timespans... 450/2047
# Running over timespans... 600/2047
# Running over timespans... 750/2047
# Running over timespans... 900/2047
# Running over timespans... 1050/2047
# Running over timespans... 1200/2047
# Running over timespans... 1350/2047
# Running over timespans... 1500/2047
# Running over timespans... 1650/2047
# Running over timespans... 1800/2047
# Running over timespans... 1950/2047
# Extracting for state 10 : ERROR
# Finding data of property CalibrationBox_LaserInfoCode... 9/498
# Extracting for state 0 : OFF
# Running over timespans... 0/27
# Extracting for state 1 : DATA_MONITORING
# Extracting for state 2 : MONITORED
# Extracting for state 3 : SAFE
# Running over timespans... 0/56
# Extracting for state 4 : STANDBY
# Running over timespans... 0/119
# Extracting for state 5 : READY
# Running over timespans... 0/1288
# Running over timespans... 150/1288
# Running over timespans... 300/1288
# Running over timespans... 450/1288
# Running over timespans... 600/1288
# Running over timespans... 750/1288
# Running over timespans... 900/1288
# Running over timespans... 1050/1288
# Running over timespans... 1200/1288
# Extracting for state 6 : OBSERVING
# Running over timespans... 0/508
# Running over timespans... 150/508
# Running over timespans... 300/508
# Running over timespans... 450/508
# Extracting for state 7 : TPOINT
# Running over timespans... 0/34
# Extracting for state 8 : UNDEFINED
# Running over timespans... 0/41
# Extracting for state 9 : TRANSITIONAL
# Running over timespans... 0/2047
# Running over timespans... 150/2047
# Running over timespans... 300/2047
# Running over timespans... 450/2047
# Running over timespans... 600/2047
# Running over timespans... 750/2047
# Running over timespans... 900/2047
# Running over timespans... 1050/2047
# Running over timespans... 1200/2047
# Running over timespans... 1350/2047
# Running over timespans... 1500/2047
# Running over timespans... 1650/2047
# Running over timespans... 1800/2047
# Running over timespans... 1950/2047
# Extracting for state 10 : ERROR
# Finding data of property CalibrationBox_LaserStatus... 10/498
# Extracting for state 0 : OFF
# Running over timespans... 0/27
# Extracting for state 1 : DATA_MONITORING
# Extracting for state 2 : MONITORED
# Extracting for state 3 : SAFE
# Running over timespans... 0/56
# Extracting for state 4 : STANDBY
# Running over timespans... 0/119
# Extracting for state 5 : READY
# Running over timespans... 0/1288
# Running over timespans... 150/1288
# Running over timespans... 300/1288
# Running over timespans... 450/1288
# Running over timespans... 600/1288
# Running over timespans... 750/1288
# Running over timespans... 900/1288
# Running over timespans... 1050/1288
# Running over timespans... 1200/1288
# Extracting for state 6 : OBSERVING
# Running over timespans... 0/508
# Running over timespans... 150/508
# Running over timespans... 300/508
# Running over timespans... 450/508
# Extracting for state 7 : TPOINT
# Running over timespans... 0/34
# Extracting for state 8 : UNDEFINED
# Running over timespans... 0/41
# Extracting for state 9 : TRANSITIONAL
# Running over timespans... 0/2047
# Running over timespans... 150/2047
# Running over timespans... 300/2047
# Running over timespans... 450/2047
# Running over timespans... 600/2047
# Running over timespans... 750/2047
# Running over timespans... 900/2047
# Running over timespans... 1050/2047
# Running over timespans... 1200/2047
# Running over timespans... 1350/2047
# Running over timespans... 1500/2047
# Running over timespans... 1650/2047
# Running over timespans... 1800/2047
# Running over timespans... 1950/2047
# Extracting for state 10 : ERROR
# Finding data of property CalibrationBox_LaserTrigParameters... 11/498
# Extracting for state 0 : OFF
# Running over timespans... 0/27
# Extracting for state 1 : DATA_MONITORING
# Extracting for state 2 : MONITORED
# Extracting for state 3 : SAFE
# Running over timespans... 0/56
# Extracting for state 4 : STANDBY
# Running over timespans... 0/119
# Extracting for state 5 : READY
# Running over timespans... 0/1288
# Running over timespans... 150/1288
# Running over timespans... 300/1288
# Running over timespans... 450/1288
# Running over timespans... 600/1288
# Running over timespans... 750/1288
# Running over timespans... 900/1288
# Running over timespans... 1050/1288
# Running over timespans... 1200/1288
# Extracting for state 6 : OBSERVING
# Running over timespans... 0/508
# Running over timespans... 150/508
# Running over timespans... 300/508
# Running over timespans... 450/508
# Extracting for state 7 : TPOINT
# Running over timespans... 0/34
# Extracting for state 8 : UNDEFINED
# Running over timespans... 0/41
# Extracting for state 9 : TRANSITIONAL
# Running over timespans... 0/2047
# Running over timespans... 150/2047
# Running over timespans... 300/2047
# Running over timespans... 450/2047
# Running over timespans... 600/2047
# Running over timespans... 750/2047
# Running over timespans... 900/2047
# Running over timespans... 1050/2047
# Running over timespans... 1200/2047
# Running over timespans... 1350/2047
# Running over timespans... 1500/2047
# Running over timespans... 1650/2047
# Running over timespans... 1800/2047
# Running over timespans... 1950/2047
# Extracting for state 10 : ERROR
# Finding data of property CalibrationBox_PedStatus... 12/498
# Extracting for state 0 : OFF
# Running over timespans... 0/27
# Extracting for state 1 : DATA_MONITORING
# Extracting for state 2 : MONITORED
# Extracting for state 3 : SAFE
# Running over timespans... 0/56
# Extracting for state 4 : STANDBY
# Running over timespans... 0/119
# Extracting for state 5 : READY
# Running over timespans... 0/1288
# Running over timespans... 150/1288
# Running over timespans... 300/1288
# Running over timespans... 450/1288
# Running over timespans... 600/1288
# Running over timespans... 750/1288
# Running over timespans... 900/1288
# Running over timespans... 1050/1288
# Running over timespans... 1200/1288
# Extracting for state 6 : OBSERVING
# Running over timespans... 0/508
# Running over timespans... 150/508
# Running over timespans... 300/508
# Running over timespans... 450/508
# Extracting for state 7 : TPOINT
# Running over timespans... 0/34
# Extracting for state 8 : UNDEFINED
# Running over timespans... 0/41
# Extracting for state 9 : TRANSITIONAL
# Running over timespans... 0/2047
# Running over timespans... 150/2047
# Running over timespans... 300/2047
# Running over timespans... 450/2047
# Running over timespans... 600/2047
# Running over timespans... 750/2047
# Running over timespans... 900/2047
# Running over timespans... 1050/2047
# Running over timespans... 1200/2047
# Running over timespans... 1350/2047
# Running over timespans... 1500/2047
# Running over timespans... 1650/2047
# Running over timespans... 1800/2047
# Running over timespans... 1950/2047
# Extracting for state 10 : ERROR
# Finding data of property CalibrationBox_PedTrigParameters... 13/498
# Extracting for state 0 : OFF
# Running over timespans... 0/27
# Extracting for state 1 : DATA_MONITORING
# Extracting for state 2 : MONITORED
# Extracting for state 3 : SAFE
# Running over timespans... 0/56
# Extracting for state 4 : STANDBY
# Running over timespans... 0/119
# Extracting for state 5 : READY
# Running over timespans... 0/1288
# Running over timespans... 150/1288
# Running over timespans... 300/1288
# Running over timespans... 450/1288
# Running over timespans... 600/1288
# Running over timespans... 750/1288
# Running over timespans... 900/1288
# Running over timespans... 1050/1288
# Running over timespans... 1200/1288
# Extracting for state 6 : OBSERVING
# Running over timespans... 0/508
# Running over timespans... 150/508
# Running over timespans... 300/508
# Running over timespans... 450/508
# Extracting for state 7 : TPOINT
# Running over timespans... 0/34
# Extracting for state 8 : UNDEFINED
# Running over timespans... 0/41
# Extracting for state 9 : TRANSITIONAL
# Running over timespans... 0/2047
# Running over timespans... 150/2047
# Running over timespans... 300/2047
# Running over timespans... 450/2047
# Running over timespans... 600/2047
# Running over timespans... 750/2047
# Running over timespans... 900/2047
# Running over timespans... 1050/2047
# Running over timespans... 1200/2047
# Running over timespans... 1350/2047
# Running over timespans... 1500/2047
# Running over timespans... 1650/2047
# Running over timespans... 1800/2047
# Running over timespans... 1950/2047
# Extracting for state 10 : ERROR
# Finding data of property CalibrationBox_PowerStatus... 14/498
# Extracting for state 0 : OFF
# Running over timespans... 0/27
# Extracting for state 1 : DATA_MONITORING
# Extracting for state 2 : MONITORED
# Extracting for state 3 : SAFE
# Running over timespans... 0/56
# Extracting for state 4 : STANDBY
# Running over timespans... 0/119
# Extracting for state 5 : READY
# Running over timespans... 0/1288
# Running over timespans... 150/1288
# Running over timespans... 300/1288
# Running over timespans... 450/1288
# Running over timespans... 600/1288
# Running over timespans... 750/1288
# Running over timespans... 900/1288
# Running over timespans... 1050/1288
# Running over timespans... 1200/1288
# Extracting for state 6 : OBSERVING
# Running over timespans... 0/508
# Running over timespans... 150/508
# Running over timespans... 300/508
# Running over timespans... 450/508
# Extracting for state 7 : TPOINT
# Running over timespans... 0/34
# Extracting for state 8 : UNDEFINED
# Running over timespans... 0/41
# Extracting for state 9 : TRANSITIONAL
# Running over timespans... 0/2047
# Running over timespans... 150/2047
# Running over timespans... 300/2047
# Running over timespans... 450/2047
# Running over timespans... 600/2047
# Running over timespans... 750/2047
# Running over timespans... 900/2047
# Running over timespans... 1050/2047
# Running over timespans... 1200/2047
# Running over timespans... 1350/2047
# Running over timespans... 1500/2047
# Running over timespans... 1650/2047
# Running over timespans... 1800/2047
# Running over timespans... 1950/2047
# Extracting for state 10 : ERROR
# Finding data of property CalibrationBox_PowerStatusLR... 15/498
# Extracting for state 0 : OFF
# Running over timespans... 0/27
# Extracting for state 1 : DATA_MONITORING
# Extracting for state 2 : MONITORED
# Extracting for state 3 : SAFE
# Running over timespans... 0/56
# Extracting for state 4 : STANDBY
# Running over timespans... 0/119
# Extracting for state 5 : READY
# Running over timespans... 0/1288
# Running over timespans... 150/1288

# %%
fig, ax = plt.subplots(figsize=(10, 4))
for key in dict_caco_states:
    mask_key = (value_tcu == key)
    ax.plot(date_tcu[mask_key], value_str_tcu[mask_key], marker=".", ls="", color=dict_caco_state_colors[key])
ax.grid()
plt.show()
