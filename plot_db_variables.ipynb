# %%
import matplotlib.pyplot as plt
import matplotlib.dates as mdates
import numpy as np
from datetime import datetime, timedelta
import pymongo

from IPython.display import display, HTML
display(HTML("<style>.container { width:100% !important; }</style>"))

# Other external scripts
import lst1_mongodb_example
import utils

client_tcu  = pymongo.MongoClient("localhost:27017")
client_caco = pymongo.MongoClient("localhost:27018")
# Out:
# <style>.container { width:100% !important; }</style>

# %% [markdown]
# #### TCU properties:

# %%
# !python lst1_mongodb_example.py --list-available
# Out:
# ---                                          ---
# ---         Available property names         ---
# ---                                          ---
#   0 : AMC_Master_ActuatorErrorCode
#   1 : AMC_Master_ActuatorHumidity
#   2 : AMC_Master_ActuatorPosition
#   3 : AMC_Master_ActuatorPositionDeviation
#   4 : AMC_Master_ActuatorSignalStrength
#   5 : AMC_Master_ActuatorTemperature
#   6 : AMC_Master_ConfiguredZenithAngle
#   7 : AMC_Master_ErrorCode
#   8 : AMC_Master_FSM_state
#   9 : AMC_Master_FSM_transition
#  10 : AMC_Master_HeartbeatTimestamp
#  11 : AMC_Master_SlaveInTransition
#  12 : AMC_Master_SlaveStates
#  13 : AMC_Master_SlavesConnected
#  14 : AMC_Master__Enable_Heart_Beat
#  15 : AMC_Master__Error_Heart_Beat
#  16 : AMC_Master__Heart_Beat
#  17 : AMC_Master__Heart_Beat_TimeOut
#  18 : AMC_PSF_CCDPower
#  19 : AMC_PSF_CCDTemperature
#  20 : AMC_PSF_ConfiguredExposure
#  21 : AMC_PSF_CooledDown
#  22 : AMC_PSF_FSM_state
#  23 : AMC_PSF_FSM_transition
#  24 : AMC_PSF_GrowthCurve
#  25 : AMC_PSF_HeartbeatTimestamp
#  26 : AMC_PSF_Spotsize
#  27 : AMC_PSF__Enable_Heart_Beat
#  28 : AMC_PSF__Error_Heart_Beat
#  29 : AMC_PSF__Heart_Beat
#  30 : AMC_PSF_imageCCD
#  31 : AMC_PSF_imageCCDstr
#  32 : AuxControl_ArchCableTension_Cable_1_Warning
#  33 : AuxControl_ArchCableTension_Cable_1_average
#  34 : AuxControl_ArchCableTension_Cable_1_dispersion
#  35 : AuxControl_ArchCableTension_Cable_1_max
#  36 : AuxControl_ArchCableTension_Cable_1_min
#  37 : AuxControl_ArchCableTension_Cable_2_Warning
#  38 : AuxControl_ArchCableTension_Cable_2_average
#  39 : AuxControl_ArchCableTension_Cable_2_dispersion
#  40 : AuxControl_ArchCableTension_Cable_2_max
#  41 : AuxControl_ArchCableTension_Cable_2_min
#  42 : AuxControl_CDM_Camera_FPS
#  43 : AuxControl_CDM_Camera_exposure
#  44 : AuxControl_CDM_Camera_gain
#  45 : AuxControl_CDM_Camera_pixelClock
#  46 : AuxControl_CDM_Camera_pixelFormat
#  47 : AuxControl_CDM_Camera_temperatureStatus
#  48 : AuxControl_CDM_Camera_temperatureValue
#  49 : AuxControl_CDM_Circle_circle_R
#  50 : AuxControl_CDM_Circle_circle_RMS
#  51 : AuxControl_CDM_Circle_circle_RMS_stddev
#  52 : AuxControl_CDM_Circle_circle_R_stddev
#  53 : AuxControl_CDM_Circle_circle_x
#  54 : AuxControl_CDM_Circle_circle_x_stddev
#  55 : AuxControl_CDM_Circle_circle_y
#  56 : AuxControl_CDM_Circle_circle_y_stddev
#  57 : AuxControl_CDM_Displacement_displacement_x
#  58 : AuxControl_CDM_Displacement_displacement_y
#  59 : AuxControl_CDM_Displacement_rotation
#  60 : AuxControl_CDM_FPS
#  61 : AuxControl_CDM_FSM_state
#  62 : AuxControl_CDM_FSM_transition
#  63 : AuxControl_CDM_LED_x_LED_x_
#  64 : AuxControl_CDM_LED_y_LED_y_
#  65 : AuxControl_CDM_OARL_x_OARL_x_
#  66 : AuxControl_CDM_OARL_x_OARL_x_mean
#  67 : AuxControl_CDM_OARL_y_OARL_y_
#  68 : AuxControl_CDM_OARL_y_OARL_y_mean
#  69 : AuxControl_CDM_circle
#  70 : AuxControl_CDM_circleErr
#  71 : AuxControl_CDM_comment
#  72 : AuxControl_CDM_displacement
#  73 : AuxControl_CDM_exposure
#  74 : AuxControl_CDM_gain
#  75 : AuxControl_CDM_image
#  76 : AuxControl_CDM_imageName
#  77 : AuxControl_CDM_imagePath
#  78 : AuxControl_CDM_imagePath_cat
#  79 : AuxControl_CDM_libVersion
#  80 : AuxControl_CDM_nImagesGet
#  81 : AuxControl_CDM_numIntegrateImage
#  82 : AuxControl_CDM_pixelFormat
#  83 : AuxControl_CDM_rotation
#  84 : AuxControl_CDM_status
#  85 : AuxControl_CDM_swVersion
#  86 : AuxControl_CDM_timestamp
#  87 : AuxControl_CDM_timestamp_timestamp_UTC
#  88 : AuxControl_CDM_timestamp_timestamp_epoch
#  89 : AuxControl_ControlLoopTimeStamp
#  90 : AuxControl_DM_DM_East_Bottom_Aquisition_in_progress
#  91 : AuxControl_DM_DM_East_Bottom_Distance
#  92 : AuxControl_DM_DM_East_Bottom_ErrorCode
#  93 : AuxControl_DM_DM_East_Bottom_Status
#  94 : AuxControl_DM_DM_East_Bottom_Timestamp
#  95 : AuxControl_DM_DM_East_Bottom_Update_Frequency
#  96 : AuxControl_DM_DM_East_Top_Aquisition_in_progress
#  97 : AuxControl_DM_DM_East_Top_Distance
#  98 : AuxControl_DM_DM_East_Top_ErrorCode
#  99 : AuxControl_DM_DM_East_Top_Status
# 100 : AuxControl_DM_DM_East_Top_Timestamp
# 101 : AuxControl_DM_DM_East_Top_Update_Frequency
# 102 : AuxControl_DM_DM_LaserOn
# 103 : AuxControl_DM_DM_West_Bottom_Aquisition_in_progress
# 104 : AuxControl_DM_DM_West_Bottom_Distance
# 105 : AuxControl_DM_DM_West_Bottom_ErrorCode
# 106 : AuxControl_DM_DM_West_Bottom_Status
# 107 : AuxControl_DM_DM_West_Bottom_Timestamp
# 108 : AuxControl_DM_DM_West_Bottom_Update_Frequency
# 109 : AuxControl_DM_DM_West_Top_Aquisition_in_progress
# 110 : AuxControl_DM_DM_West_Top_Distance
# 111 : AuxControl_DM_DM_West_Top_ErrorCode
# 112 : AuxControl_DM_DM_West_Top_Status
# 113 : AuxControl_DM_DM_West_Top_Timestamp
# 114 : AuxControl_DM_DM_West_Top_Update_Frequency
# 115 : AuxControl_DM_East_Bottom_Aquisition_in_progress
# 116 : AuxControl_DM_East_Bottom_Distance
# 117 : AuxControl_DM_East_Bottom_ErrorCode
# 118 : AuxControl_DM_East_Bottom_Status
# 119 : AuxControl_DM_East_Bottom_Timestamp
# 120 : AuxControl_DM_East_Bottom_Update_Frequency
# 121 : AuxControl_DM_East_Top_Aquisition_in_progress
# 122 : AuxControl_DM_East_Top_Distance
# 123 : AuxControl_DM_East_Top_ErrorCode
# 124 : AuxControl_DM_East_Top_Status
# 125 : AuxControl_DM_East_Top_Timestamp
# 126 : AuxControl_DM_East_Top_Update_Frequency
# 127 : AuxControl_DM_West_Bottom_Aquisition_in_progress
# 128 : AuxControl_DM_West_Bottom_Distance
# 129 : AuxControl_DM_West_Bottom_ErrorCode
# 130 : AuxControl_DM_West_Bottom_Status
# 131 : AuxControl_DM_West_Bottom_Timestamp
# 132 : AuxControl_DM_West_Bottom_Update_Frequency
# 133 : AuxControl_DM_West_Top_Aquisition_in_progress
# 134 : AuxControl_DM_West_Top_Distance
# 135 : AuxControl_DM_West_Top_ErrorCode
# 136 : AuxControl_DM_West_Top_Status
# 137 : AuxControl_DM_West_Top_Timestamp
# 138 : AuxControl_DM_West_Top_Update_Frequency
# 139 : AuxControl_Enable_Heart_Beat
# 140 : AuxControl_Encoders_Central_Pin_Az_position_average
# 141 : AuxControl_Encoders_Central_Pin_Az_position_max
# 142 : AuxControl_Encoders_Central_Pin_Az_position_min
# 143 : AuxControl_Encoders_Central_Pin_Az_position_rms
# 144 : AuxControl_Encoders_Central_Pin_Az_velocity_average
# 145 : AuxControl_Encoders_Central_Pin_Az_velocity_max
# 146 : AuxControl_Encoders_Central_Pin_Az_velocity_min
# 147 : AuxControl_Encoders_Central_Pin_Az_velocity_rms
# 148 : AuxControl_Encoders_East_Encoder_El_position_average
# 149 : AuxControl_Encoders_East_Encoder_El_position_max
# 150 : AuxControl_Encoders_East_Encoder_El_position_min
# 151 : AuxControl_Encoders_East_Encoder_El_position_rms
# 152 : AuxControl_Encoders_East_Encoder_El_velocity_average
# 153 : AuxControl_Encoders_East_Encoder_El_velocity_max
# 154 : AuxControl_Encoders_East_Encoder_El_velocity_min
# 155 : AuxControl_Encoders_East_Encoder_El_velocity_rms
# 156 : AuxControl_Encoders_Epoch_Az_Stats
# 157 : AuxControl_Encoders_Epoch_El_Stats
# 158 : AuxControl_Encoders_West_Encoder_El_position_average
# 159 : AuxControl_Encoders_West_Encoder_El_position_max
# 160 : AuxControl_Encoders_West_Encoder_El_position_min
# 161 : AuxControl_Encoders_West_Encoder_El_position_rms
# 162 : AuxControl_Encoders_West_Encoder_El_velocity_average
# 163 : AuxControl_Encoders_West_Encoder_El_velocity_max
# 164 : AuxControl_Encoders_West_Encoder_El_velocity_min
# 165 : AuxControl_Encoders_West_Encoder_El_velocity_rms
# 166 : AuxControl_Error_Heart_Beat
# 167 : AuxControl_FSM_state
# 168 : AuxControl_FSM_transition
# 169 : AuxControl_Heart_Beat
# 170 : AuxControl_Heart_Beat_TimeOut
# 171 : AuxControl_Inclinometer_Angle
# 172 : AuxControl_Inclinometer_ElevationAxis_Id
# 173 : AuxControl_Inclinometer_ElevationAxis_Principal_Angle
# 174 : AuxControl_Inclinometer_ElevationAxis_Secondary_Angle
# 175 : AuxControl_Inclinometer_ElevationAxis_Temperature
# 176 : AuxControl_Inclinometer_ElevationAxis_Timestamp
# 177 : AuxControl_Inclinometer_OpticalAxis_Id
# 178 : AuxControl_Inclinometer_OpticalAxis_Principal_Angle
# 179 : AuxControl_Inclinometer_OpticalAxis_Secondary_Angle
# 180 : AuxControl_Inclinometer_OpticalAxis_Temperature
# 181 : AuxControl_Inclinometer_OpticalAxis_Timestamp
# 182 : AuxControl_Motors_Azimuth_Az_torque_average
# 183 : AuxControl_Motors_Azimuth_Az_torque_max
# 184 : AuxControl_Motors_Azimuth_Az_torque_min
# 185 : AuxControl_Motors_Azimuth_Az_torque_rms
# 186 : AuxControl_Motors_Elevation_El_torque_average
# 187 : AuxControl_Motors_Elevation_El_torque_max
# 188 : AuxControl_Motors_Elevation_El_torque_min
# 189 : AuxControl_Motors_Elevation_El_torque_rms
# 190 : AuxControl_Motors_Epoch_Az_Stats
# 191 : AuxControl_Motors_Epoch_El_Stats
# 192 : AuxControl_OARL_ErrorCode
# 193 : AuxControl_OARL_Status
# 194 : AuxControl_Power_AMC_I
# 195 : AuxControl_Power_AMC_In
# 196 : AuxControl_Power_AMC_P
# 197 : AuxControl_Power_Air_Conditionner_I
# 198 : AuxControl_Power_Air_Conditionner_In
# 199 : AuxControl_Power_Air_Conditionner_P
# 200 : AuxControl_Power_CameraMain_Frame_I
# 201 : AuxControl_Power_CameraMain_Frame_In
# 202 : AuxControl_Power_CameraMain_Frame_P
# 203 : AuxControl_Power_CameraMain_Tower_I
# 204 : AuxControl_Power_CameraMain_Tower_In
# 205 : AuxControl_Power_CameraMain_Tower_P
# 206 : AuxControl_Power_CameraUPS_I
# 207 : AuxControl_Power_CameraUPS_In
# 208 : AuxControl_Power_CameraUPS_P
# 209 : AuxControl_Power_Chiller_I
# 210 : AuxControl_Power_Chiller_In
# 211 : AuxControl_Power_Chiller_P
# 212 : AuxControl_Power_DishCenterMain_I
# 213 : AuxControl_Power_DishCenterMain_In
# 214 : AuxControl_Power_DishCenterMain_P
# 215 : AuxControl_Power_DishCenter_I
# 216 : AuxControl_Power_DishCenter_In
# 217 : AuxControl_Power_DishCenter_P
# 218 : AuxControl_Power_DriveContainerPCs_I
# 219 : AuxControl_Power_DriveContainerPCs_In
# 220 : AuxControl_Power_DriveContainerPCs_P
# 221 : AuxControl_Power_Drive_Azimuth_I
# 222 : AuxControl_Power_Drive_Azimuth_In
# 223 : AuxControl_Power_Drive_Azimuth_P
# 224 : AuxControl_Power_Drive_Elevation_I
# 225 : AuxControl_Power_Drive_Elevation_In
# 226 : AuxControl_Power_Drive_Elevation_P
# 227 : AuxControl_Power_ErrorCode
# 228 : AuxControl_Power_Main_Power_I
# 229 : AuxControl_Power_Main_Power_In
# 230 : AuxControl_Power_Main_Power_P
# 231 : AuxControl_Power_Spare_I
# 232 : AuxControl_Power_Spare_In
# 233 : AuxControl_Power_Spare_P
# 234 : AuxControl_Power_Status
# 235 : AuxControl_RemotePowerCtrl_CalibBoxLaserRelay_Cmd_Status
# 236 : AuxControl_RemotePowerCtrl_CalibBoxLaserRelay_Status
# 237 : AuxControl_RemotePowerCtrl_CalibBoxRelay_Cmd_Status
# 238 : AuxControl_RemotePowerCtrl_CalibBoxRelay_Status
# 239 : AuxControl_RemotePowerCtrl_NUCRelay_Cmd_Status
# 240 : AuxControl_RemotePowerCtrl_NUCRelay_Status
# 241 : AuxControl_RemotePowerCtrl_OARLRelay_Cmd_Status
# 242 : AuxControl_RemotePowerCtrl_OARLRelay_Status
# 243 : AuxControl_RemotePowerCtrl_PSFCamRelay_Cmd_Status
# 244 : AuxControl_RemotePowerCtrl_PSFCamRelay_Status
# 245 : AuxControl_RemotePowerCtrl_SGRelay_Cmd_Status
# 246 : AuxControl_RemotePowerCtrl_SGRelay_Status
# 247 : AuxControl_SG_sgComment
# 248 : AuxControl_SG_sgExposure
# 249 : AuxControl_SG_sgFPS
# 250 : AuxControl_SG_sgGain
# 251 : AuxControl_SG_sgGamma
# 252 : AuxControl_SG_sgIP
# 253 : AuxControl_SG_sgImage
# 254 : AuxControl_SG_sgImageConfig
# 255 : AuxControl_SG_sgImageName
# 256 : AuxControl_SG_sgImagePath
# 257 : AuxControl_SG_sgImageValid
# 258 : AuxControl_SG_sgLSTcircle
# 259 : AuxControl_SG_sgLSTcirclesErr
# 260 : AuxControl_SG_sgLibVersion
# 261 : AuxControl_SG_sgMeanSkyIntensity
# 262 : AuxControl_SG_sgNumDetectedStars
# 263 : AuxControl_SG_sgNumMatchedStars
# 264 : AuxControl_SG_sgPixelFormat
# 265 : AuxControl_SG_sgStatus
# 266 : AuxControl_SG_sgTempStatus
# 267 : AuxControl_SG_sgTimestamp
# 268 : AuxControl_Sensor_hoodHumid
# 269 : AuxControl_Sensor_hoodPressure
# 270 : AuxControl_Sensor_hoodTemp
# 271 : AuxControl_Sensor_humidity
# 272 : AuxControl_Sensor_humidity_absolute
# 273 : AuxControl_Sensor_humidity_relative
# 274 : AuxControl_Sensor_pressure
# 275 : AuxControl_Sensor_temperature
# 276 : AuxControl_Test
# 277 : AuxControl_WS_Monitoring_Absolute_Air_Pressure
# 278 : AuxControl_WS_Monitoring_Absolute_Humidity
# 279 : AuxControl_WS_Monitoring_Air_Temperature
# 280 : AuxControl_WS_Monitoring_Azimuth_Position_Sun
# 281 : AuxControl_WS_Monitoring_Brightness
# 282 : AuxControl_WS_Monitoring_Compass_Direction
# 283 : AuxControl_WS_Monitoring_Dew_Point_Temperature
# 284 : AuxControl_WS_Monitoring_Elevation_Position_Sun
# 285 : AuxControl_WS_Monitoring_GPS_Operating
# 286 : AuxControl_WS_Monitoring_Global_Radiation
# 287 : AuxControl_WS_Monitoring_Precipitation
# 288 : AuxControl_WS_Monitoring_Precipitation_Difference
# 289 : AuxControl_WS_Monitoring_Precipitation_Intensity
# 290 : AuxControl_WS_Monitoring_Precipitation_Type
# 291 : AuxControl_WS_Monitoring_Refresh
# 292 : AuxControl_WS_Monitoring_Relative_Air_Pressure
# 293 : AuxControl_WS_Monitoring_Relative_Humidity
# 294 : AuxControl_WS_Monitoring_Run_Time
# 295 : AuxControl_WS_Monitoring_Twilight
# 296 : AuxControl_WS_Monitoring_UTC_Time_High
# 297 : AuxControl_WS_Monitoring_UTC_Time_Low
# 298 : AuxControl_WS_Monitoring_UV_Index
# 299 : AuxControl_WS_Monitoring_Wind_Direction
# 300 : AuxControl_WS_Monitoring_Wind_Direction_Compass
# 301 : AuxControl_WS_Status_Brightness_Sensor
# 302 : AuxControl_WS_Status_Device_Status_high
# 303 : AuxControl_WS_Status_Device_Status_low
# 304 : AuxControl_WS_Status_Humidity_Sensor
# 305 : AuxControl_WS_Status_ModbusConnection_Sensor
# 306 : AuxControl_WS_Status_Precipitation_Sensor
# 307 : AuxControl_WS_Status_Pressure_Sensor
# 308 : AuxControl_WS_Status_Radiation_Sensor
# 309 : AuxControl_WS_Status_Temperature_Sensor
# 310 : AuxControl_WS_Status_UV_Index_Sensor
# 311 : AuxControl_WS_Status_Wifi_Sensor
# 312 : AuxControl_WS_Status_Wind_Sensor
# 313 : AuxControl__ControlLoopTimeStamp
# 314 : AuxControl__Enable_Heart_Beat
# 315 : AuxControl__Error_Heart_Beat
# 316 : AuxControl__Heart_Beat
# 317 : AuxControl__Heart_Beat_TimeOut
# 318 : AuxControl_state
# 319 : AuxControl_swVersion
# 320 : CDM2_Exposure
# 321 : CDM2_FPS
# 322 : CDM2_ImagePath
# 323 : CDM2_PixelClock
# 324 : CDM2_StarName
# 325 : CalibrationBox_BG_InterCalibration_Mean
# 326 : CalibrationBox_DewPoint
# 327 : CalibrationBox_Error_BG_InterCalibration_Mean
# 328 : CalibrationBox_Error_InterCalibration_Mean
# 329 : CalibrationBox_FSM_state
# 330 : CalibrationBox_FSM_transition
# 331 : CalibrationBox_Humidity
# 332 : CalibrationBox_InterCalibration_Mean
# 333 : CalibrationBox_LaserErrorCode
# 334 : CalibrationBox_LaserInfoCode
# 335 : CalibrationBox_LaserStatus
# 336 : CalibrationBox_LaserTrigParameters
# 337 : CalibrationBox_PedStatus
# 338 : CalibrationBox_PedTrigParameters
# 339 : CalibrationBox_PowerStatus
# 340 : CalibrationBox_PowerStatusLR
# 341 : CalibrationBox_Pressure
# 342 : CalibrationBox_Temperature
# 343 : CalibrationBox_WheelPosition
# 344 : Calibration_CalibrationBox_Humidity
# 345 : Calibration_CalibrationBox_LaserErrorCode
# 346 : Calibration_CalibrationBox_LaserInfoCode
# 347 : Calibration_CalibrationBox_LaserStatus
# 348 : Calibration_CalibrationBox_LaserTrigParameters
# 349 : Calibration_CalibrationBox_PowerStatus
# 350 : Calibration_CalibrationBox_Pressure
# 351 : Calibration_CalibrationBox_Temperature
# 352 : Calibration_CalibrationBox_WheelPosition
# 353 : CameraControl_CBOXControl_state
# 354 : CameraControl_FSM_is_transit
# 355 : CameraControl_FSM_is_warm_up
# 356 : CameraControl_FSM_previous_state
# 357 : CameraControl_FSM_state
# 358 : CameraControl_InstrumentProtection_mode
# 359 : CameraControl_InstrumentProtection_status
# 360 : CameraControl_MessageAdviser_last_message
# 361 : CameraControl_ModulesAvailable_CBOX_valid_connection
# 362 : CameraControl_ModulesAvailable_CLUS_valid_connection
# 363 : CameraControl_ModulesAvailable_DAQ_valid_connection
# 364 : CameraControl_ModulesAvailable_ECC_valid_connection
# 365 : CameraControl_ModulesAvailable_Sphe_valid_connection
# 366 : CameraControl_ModulesAvailable_TIB_valid_connection
# 367 : CameraControl_ModulesAvailable_UCTS_valid_connection
# 368 : CameraControl_ModulesStatus_CLUSCO
# 369 : CameraControl_ModulesStatus_CS
# 370 : CameraControl_ModulesStatus_DAQ
# 371 : CameraControl_ModulesStatus_ECC
# 372 : CameraControl_ModulesStatus_SIS
# 373 : CameraControl_ModulesStatus_TIB
# 374 : CameraControl_ModulesStatus_UCTS
# 375 : CameraControl_RunUtils_is_test
# 376 : CameraControl_RunUtils_run_number
# 377 : CameraControl_UserAdviser_message
# 378 : CameraControl__ControlLoopTimeStamp
# 379 : CameraControl_heartbeat_caco_timestamp
# 380 : CameraControl_heartbeat_enabled
# 381 : CameraControl_heartbeat_time_limit
# 382 : CameraControl_heartbeat_times_failed
# 383 : CameraControl_information_MessageAdviser_last_message
# 384 : CameraControl_information_error_state
# 385 : Camera_CalibrationBox_BG_InterCalibration_Mean
# 386 : Camera_CalibrationBox_DewPoint
# 387 : Camera_CalibrationBox_Error_BG_InterCalibration_Mean
# 388 : Camera_CalibrationBox_Error_InterCalibration_Mean
# 389 : Camera_CalibrationBox_Humidity
# 390 : Camera_CalibrationBox_InterCalibration_Mean
# 391 : Camera_CalibrationBox_LaserErrorCode
# 392 : Camera_CalibrationBox_LaserInfoCode
# 393 : Camera_CalibrationBox_LaserStatus
# 394 : Camera_CalibrationBox_LaserTrigParameters
# 395 : Camera_CalibrationBox_PedRndTrigParameter
# 396 : Camera_CalibrationBox_PedStatus
# 397 : Camera_CalibrationBox_PedTrigParameters
# 398 : Camera_CalibrationBox_PowerStatus
# 399 : Camera_CalibrationBox_PowerStatusLR
# 400 : Camera_CalibrationBox_Pressure
# 401 : Camera_CalibrationBox_Temperature
# 402 : Camera_CalibrationBox_WheelPosition
# 403 : Camera_UCTS_ConfigurationParameters_CDTS_MAC_Address
# 404 : Camera_UCTS_ConfigurationParameters_OPCUA_server_IP_Address
# 405 : Camera_UCTS_ConfigurationParameters_UCTS_IP_Address
# 406 : Camera_UCTS_Configuration_UctsIpAddr
# 407 : Camera_UCTS_FSM_state
# 408 : Camera_UCTS_FSM_transition
# 409 : Camera_UCTS_HardwareConfig_state
# 410 : Camera_UCTS_SNMPParameters_SNMP_Port_Link_Status
# 411 : Camera_UCTS_SNMPParameters_SNMP_Temperature
# 412 : Camera_UCTS_SNMPParameters_SNMP_Time_TAI
# 413 : Camera_UCTS_SNMPParameters_SNMP_Up_Time
# 414 : Camera_UCTS_SNMPParameters_SNMP_wrpc_Sw_Version
# 415 : Camera_UCTS_SNMP_BusyCount
# 416 : Camera_UCTS_SNMP_DstIpAddr
# 417 : Camera_UCTS_SNMP_DstMacAddr
# 418 : Camera_UCTS_SNMP_DstPort
# 419 : Camera_UCTS_SNMP_EventCount
# 420 : Camera_UCTS_SNMP_PortLinkStatus
# 421 : Camera_UCTS_SNMP_Status
# 422 : Camera_UCTS_SNMP_Temperature
# 423 : Camera_UCTS_SNMP_Throttle
# 424 : Camera_UCTS_SNMP_TimeTAI
# 425 : Camera_UCTS_SNMP_UpTime
# 426 : Camera_UCTS_SNMP_WrpcSwVersion
# 427 : Camera__ControlLoopTimeStamp
# 428 : Camera__Enable_Heart_Beat
# 429 : Camera__Error_Heart_Beat
# 430 : Camera__Heart_Beat
# 431 : DriveControl_ArchCableTension_Cable_1_average
# 432 : DriveControl_ArchCableTension_Cable_1_dispersion
# 433 : DriveControl_ArchCableTension_Cable_1_fft_signal
# 434 : DriveControl_ArchCableTension_Cable_1_max
# 435 : DriveControl_ArchCableTension_Cable_1_min
# 436 : DriveControl_ArchCableTension_Cable_1_oscillationFrequency
# 437 : DriveControl_ArchCableTension_Cable_2_average
# 438 : DriveControl_ArchCableTension_Cable_2_dispersion
# 439 : DriveControl_ArchCableTension_Cable_2_fft_signal
# 440 : DriveControl_ArchCableTension_Cable_2_max
# 441 : DriveControl_ArchCableTension_Cable_2_min
# 442 : DriveControl_ArchCableTension_Cable_2_oscillationFrequency
# 443 : DriveControl_Azimuth_Offset
# 444 : DriveControl_BendingModelCorrection_Az
# 445 : DriveControl_BendingModelCorrection_Zd
# 446 : DriveControl_BendingModel_Content
# 447 : DriveControl_BendingModel_Id
# 448 : DriveControl_BendingModel_LoadedRef
# 449 : DriveControl_CalibrationFastGoToPositionRange
# 450 : DriveControl_CalibrationGoToPositionRange
# 451 : DriveControl_CalibrationTrackingRange
# 452 : DriveControl_Config_Azimuth_FastPositioning_Acceleration
# 453 : DriveControl_Config_Azimuth_FastPositioning_Deceleration
# 454 : DriveControl_Config_Azimuth_FastPositioning_Jerk
# 455 : DriveControl_Config_Azimuth_FastPositioning_Speed
# 456 : DriveControl_Config_Azimuth_FastPositioning_Torque_Limit_Perc
# 457 : DriveControl_Config_Azimuth_NormalPositioning_Acceleration
# 458 : DriveControl_Config_Azimuth_NormalPositioning_Deceleration
# 459 : DriveControl_Config_Azimuth_NormalPositioning_Jerk
# 460 : DriveControl_Config_Azimuth_NormalPositioning_PositioningAcceleration
# 461 : DriveControl_Config_Azimuth_NormalPositioning_PositioningDeceleration
# 462 : DriveControl_Config_Azimuth_NormalPositioning_Speed
# 463 : DriveControl_Config_Azimuth_NormalPositioning_Torque_Limit_Perc
# 464 : DriveControl_Config_Elevation_FastPositioning_Acceleration
# 465 : DriveControl_Config_Elevation_FastPositioning_Deceleration
# 466 : DriveControl_Config_Elevation_FastPositioning_Jerk
# 467 : DriveControl_Config_Elevation_FastPositioning_Speed
# 468 : DriveControl_Config_Elevation_FastPositioning_Torque_Limit_Perc
# 469 : DriveControl_Config_Elevation_NormalPositioning_Acceleration
# 470 : DriveControl_Config_Elevation_NormalPositioning_Deceleration
# 471 : DriveControl_Config_Elevation_NormalPositioning_Jerk
# 472 : DriveControl_Config_Elevation_NormalPositioning_Speed
# 473 : DriveControl_Config_Elevation_NormalPositioning_Torque_Limit_Perc
# 474 : DriveControl_ControlLoopTimeStamp
# 475 : DriveControl_ControllerVersion
# 476 : DriveControl_CurrentPosition_azimuth_position
# 477 : DriveControl_CurrentPosition_azimuth_timestamp
# 478 : DriveControl_CurrentPosition_azimuth_velocity
# 479 : DriveControl_CurrentPosition_elevation_position
# 480 : DriveControl_CurrentPosition_elevation_velocity
# 481 : DriveControl_CurrentPosition_zenithangle_position
# 482 : DriveControl_CurrentPosition_zenithangle_timestamp
# 483 : DriveControl_CurrentPosition_zenithangle_velocity
# 484 : DriveControl_Dec
# 485 : DriveControl_Dec_OffsetSG
# 486 : DriveControl_Dec_Target
# 487 : DriveControl_Dec_Telescope
# 488 : DriveControl_DriveConfigId
# 489 : DriveControl_DriveTelId
# 490 : DriveControl_Enable_Heart_Beat
# 491 : DriveControl_Encoders_Central_Pin_Az_position_average
# 492 : DriveControl_Encoders_Central_Pin_Az_position_max
# 493 : DriveControl_Encoders_Central_Pin_Az_position_min
# 494 : DriveControl_Encoders_Central_Pin_Az_position_rms
# 495 : DriveControl_Encoders_Central_Pin_Az_velocity_average
# 496 : DriveControl_Encoders_Central_Pin_Az_velocity_max
# 497 : DriveControl_Encoders_Central_Pin_Az_velocity_min
# 498 : DriveControl_Encoders_Central_Pin_Az_velocity_rms
# 499 : DriveControl_Encoders_East_Encoder_El_position_average
# 500 : DriveControl_Encoders_East_Encoder_El_position_max
# 501 : DriveControl_Encoders_East_Encoder_El_position_min
# 502 : DriveControl_Encoders_East_Encoder_El_position_rms
# 503 : DriveControl_Encoders_East_Encoder_El_velocity_average
# 504 : DriveControl_Encoders_East_Encoder_El_velocity_max
# 505 : DriveControl_Encoders_East_Encoder_El_velocity_min
# 506 : DriveControl_Encoders_East_Encoder_El_velocity_rms
# 507 : DriveControl_Encoders_West_Encoder_El_position_average
# 508 : DriveControl_Encoders_West_Encoder_El_position_max
# 509 : DriveControl_Encoders_West_Encoder_El_position_min
# 510 : DriveControl_Encoders_West_Encoder_El_position_rms
# 511 : DriveControl_Encoders_West_Encoder_El_velocity_average
# 512 : DriveControl_Encoders_West_Encoder_El_velocity_max
# 513 : DriveControl_Encoders_West_Encoder_El_velocity_min
# 514 : DriveControl_Encoders_West_Encoder_El_velocity_rms
# 515 : DriveControl_Error_Heart_Beat
# 516 : DriveControl_FSM_state
# 517 : DriveControl_FSM_transition
# 518 : DriveControl_Heart_Beat
# 519 : DriveControl_Heart_Beat_TimeOut
# 520 : DriveControl_Locking_ALS_Azimuth_in_position
# 521 : DriveControl_Locking_ALS_East_Locked
# 522 : DriveControl_Locking_ALS_East_North_LoadCell
# 523 : DriveControl_Locking_ALS_East_South_LoadCell
# 524 : DriveControl_Locking_ALS_East_Unlocked
# 525 : DriveControl_Locking_ALS_Error
# 526 : DriveControl_Locking_ALS_Error_Code
# 527 : DriveControl_Locking_ALS_Motion_Allowed
# 528 : DriveControl_Locking_ALS_Negative_Over_Travel
# 529 : DriveControl_Locking_ALS_Positive_Over_Travel
# 530 : DriveControl_Locking_ALS_West_Locked
# 531 : DriveControl_Locking_ALS_West_North_LoadCell
# 532 : DriveControl_Locking_ALS_West_South_LoadCell
# 533 : DriveControl_Locking_ALS_West_Unlocked
# 534 : DriveControl_Locking_ELS_Error
# 535 : DriveControl_Locking_ELS_Error_Code
# 536 : DriveControl_Locking_ELS_Locked
# 537 : DriveControl_Locking_ELS_Motion_Allowed
# 538 : DriveControl_Locking_ELS_Negative_Over_Travel
# 539 : DriveControl_Locking_ELS_Positive_Over_Travel
# 540 : DriveControl_Locking_ELS_Unlocked
# 541 : DriveControl_Locking_Site_North_Pedes_Door_Closed
# 542 : DriveControl_Locking_Site_OK_ForCommand
# 543 : DriveControl_Locking_Site_South_Pedes_Door_Closed
# 544 : DriveControl_Locking_Site_West_Car_Door_Closed
# 545 : DriveControl_Locking_Telescope_On_Emergency_Stop_State
# 546 : DriveControl_Locking_Tower_CSS_In_Position
# 547 : DriveControl_Locking_Tower_CSS_is_Locked
# 548 : DriveControl_Locking_Tower_CSS_is_Unlocked
# 549 : DriveControl_Locking_Tower_Tower_can_be_Operated
# 550 : DriveControl_Locking_Tower_Tower_is_Closed
# 551 : DriveControl_Locking_Tower_Tower_is_Open
# 552 : DriveControl_Locking_UC_All_Ok
# 553 : DriveControl_Locking_UC_Auto_Park_In_Req
# 554 : DriveControl_Locking_UC_Drive_Stop_Required
# 555 : DriveControl_Locking_UC_FW1
# 556 : DriveControl_Locking_UC_FW7
# 557 : DriveControl_Locking_UC_GRB_is_Disabled
# 558 : DriveControl_Locking_UC_OK_for_GRB_Motion
# 559 : DriveControl_Locking_UC_OK_for_Normal_Motion
# 560 : DriveControl_Locking_UC_UPS
# 561 : DriveControl_Log_Log_Error
# 562 : DriveControl_Log_Log_ErrorCode
# 563 : DriveControl_Log_Log_Print
# 564 : DriveControl_Log_Log_Warning
# 565 : DriveControl_MotionLog_Azimuth_Accel_End_Time
# 566 : DriveControl_MotionLog_Azimuth_Accel_Start_Time
# 567 : DriveControl_MotionLog_Azimuth_Decel_End_Time
# 568 : DriveControl_MotionLog_Azimuth_Decel_Start_Time
# 569 : DriveControl_MotionLog_Azimuth_Track_Approach_End_Time
# 570 : DriveControl_MotionLog_Azimuth_Track_Approach_Start_Time
# 571 : DriveControl_MotionLog_Azimuth_Track_Decel_End_Time
# 572 : DriveControl_MotionLog_Azimuth_Track_Decel_Start_Time
# 573 : DriveControl_MotionLog_Azimuth_Track_Regul_End_Time
# 574 : DriveControl_MotionLog_Azimuth_Track_Regul_Start_Time
# 575 : DriveControl_MotionLog_Elevation_Accel_End_Time
# 576 : DriveControl_MotionLog_Elevation_Accel_Start_Time
# 577 : DriveControl_MotionLog_Elevation_Decel_End_Time
# 578 : DriveControl_MotionLog_Elevation_Decel_Start_Time
# 579 : DriveControl_MotionLog_Elevation_Track_Approach_End_Time
# 580 : DriveControl_MotionLog_Elevation_Track_Approach_Start_Time
# 581 : DriveControl_MotionLog_Elevation_Track_Decel_End_Time
# 582 : DriveControl_MotionLog_Elevation_Track_Decel_Start_Time
# 583 : DriveControl_MotionLog_Elevation_Track_Regul_End_Time
# 584 : DriveControl_MotionLog_Elevation_Track_Regul_Start_Time
# 585 : DriveControl_Motors_AzimuthRefPosition_Epoch_Az_Stats
# 586 : DriveControl_Motors_AzimuthRefPosition_Monitoring_Period_s
# 587 : DriveControl_Motors_AzimuthRefPosition_average
# 588 : DriveControl_Motors_AzimuthRefPosition_error
# 589 : DriveControl_Motors_AzimuthRefPosition_error_average
# 590 : DriveControl_Motors_AzimuthRefPosition_error_max
# 591 : DriveControl_Motors_AzimuthRefPosition_error_min
# 592 : DriveControl_Motors_AzimuthRefPosition_error_rms
# 593 : DriveControl_Motors_AzimuthRefPosition_max
# 594 : DriveControl_Motors_AzimuthRefPosition_min
# 595 : DriveControl_Motors_AzimuthRefPosition_rms
# 596 : DriveControl_Motors_Azimuth_Az_accuracy_average
# 597 : DriveControl_Motors_Azimuth_Az_accuracy_max
# 598 : DriveControl_Motors_Azimuth_Az_accuracy_min
# 599 : DriveControl_Motors_Azimuth_Az_accuracy_rms
# 600 : DriveControl_Motors_Azimuth_Az_position_average
# 601 : DriveControl_Motors_Azimuth_Az_position_max
# 602 : DriveControl_Motors_Azimuth_Az_position_min
# 603 : DriveControl_Motors_Azimuth_Az_position_rms
# 604 : DriveControl_Motors_Azimuth_Az_torque_average
# 605 : DriveControl_Motors_Azimuth_Az_torque_max
# 606 : DriveControl_Motors_Azimuth_Az_torque_min
# 607 : DriveControl_Motors_Azimuth_Az_torque_rms
# 608 : DriveControl_Motors_Azimuth_Az_velocity_average
# 609 : DriveControl_Motors_Azimuth_Az_velocity_max
# 610 : DriveControl_Motors_Azimuth_Az_velocity_min
# 611 : DriveControl_Motors_Azimuth_Az_velocity_rms
# 612 : DriveControl_Motors_ElevationRefPosition_Epoch_El_Stats
# 613 : DriveControl_Motors_ElevationRefPosition_Monitoring_Period_s
# 614 : DriveControl_Motors_ElevationRefPosition_average
# 615 : DriveControl_Motors_ElevationRefPosition_error
# 616 : DriveControl_Motors_ElevationRefPosition_error_average
# 617 : DriveControl_Motors_ElevationRefPosition_error_max
# 618 : DriveControl_Motors_ElevationRefPosition_error_min
# 619 : DriveControl_Motors_ElevationRefPosition_error_rms
# 620 : DriveControl_Motors_ElevationRefPosition_max
# 621 : DriveControl_Motors_ElevationRefPosition_min
# 622 : DriveControl_Motors_ElevationRefPosition_rms
# 623 : DriveControl_Motors_Elevation_El_accuracy_average
# 624 : DriveControl_Motors_Elevation_El_accuracy_max
# 625 : DriveControl_Motors_Elevation_El_accuracy_min
# 626 : DriveControl_Motors_Elevation_El_accuracy_rms
# 627 : DriveControl_Motors_Elevation_El_position_average
# 628 : DriveControl_Motors_Elevation_El_position_max
# 629 : DriveControl_Motors_Elevation_El_position_min
# 630 : DriveControl_Motors_Elevation_El_position_rms
# 631 : DriveControl_Motors_Elevation_El_torque_average
# 632 : DriveControl_Motors_Elevation_El_torque_max
# 633 : DriveControl_Motors_Elevation_El_torque_min
# 634 : DriveControl_Motors_Elevation_El_torque_rms
# 635 : DriveControl_Motors_Elevation_El_velocity_average
# 636 : DriveControl_Motors_Elevation_El_velocity_max
# 637 : DriveControl_Motors_Elevation_El_velocity_min
# 638 : DriveControl_Motors_Elevation_El_velocity_rms
# 639 : DriveControl_ParkoutDefaultPosition_Azimuth
# 640 : DriveControl_ParkoutDefaultPosition_Elevation
# 641 : DriveControl_Plc_activity
# 642 : DriveControl_Plc_step_description
# 643 : DriveControl_Plc_step_num
# 644 : DriveControl_RA
# 645 : DriveControl_RADec_Telescope_TimeStamp
# 646 : DriveControl_RA_OffsetSG
# 647 : DriveControl_RA_Target
# 648 : DriveControl_RA_Telescope
# 649 : DriveControl_SourceName
# 650 : DriveControl_Status_Az_Tracking_is_Correct
# 651 : DriveControl_Status_El_Tracking_is_Correct
# 652 : DriveControl_Status_PositioningCmd_Azimuth_Acceleration
# 653 : DriveControl_Status_PositioningCmd_Azimuth_Deceleration
# 654 : DriveControl_Status_PositioningCmd_Azimuth_Jerk
# 655 : DriveControl_Status_PositioningCmd_Azimuth_Position
# 656 : DriveControl_Status_PositioningCmd_Azimuth_Speed
# 657 : DriveControl_Status_PositioningCmd_ZenithAngle_Acceleration
# 658 : DriveControl_Status_PositioningCmd_ZenithAngle_Deceleration
# 659 : DriveControl_Status_PositioningCmd_ZenithAngle_Jerk
# 660 : DriveControl_Status_PositioningCmd_ZenithAngle_Position
# 661 : DriveControl_Status_PositioningCmd_ZenithAngle_Speed
# 662 : DriveControl_Status_PositioningMax_Azimuth_Torque_Perc
# 663 : DriveControl_Status_PositioningMax_ZenithAngle_Torque_Perc
# 664 : DriveControl_Status_Status_Automatic_Park_InProgress
# 665 : DriveControl_Status_Status_Busy
# 666 : DriveControl_Status_Status_Cmd
# 667 : DriveControl_Status_Status_Drive_Powered
# 668 : DriveControl_Status_Status_Error_Code
# 669 : DriveControl_Status_Status_Global
# 670 : DriveControl_Status_Status_In_Manual_Mode
# 671 : DriveControl_Status_Status_In_Motion
# 672 : DriveControl_Status_Status_In_Parking_Position
# 673 : DriveControl_Status_Status_Motion_Allowed
# 674 : DriveControl_Status_Status_Parked
# 675 : DriveControl_Status_Status_Ready_for_Motion
# 676 : DriveControl_Status_Status_Tracking_In_Progress
# 677 : DriveControl_Status_TrackingMax_Azimuth_Acceleration
# 678 : DriveControl_Status_TrackingMax_Azimuth_Deceleration
# 679 : DriveControl_Status_TrackingMax_Azimuth_Jerk
# 680 : DriveControl_Status_TrackingMax_Azimuth_Position
# 681 : DriveControl_Status_TrackingMax_Azimuth_Speed
# 682 : DriveControl_Status_TrackingMax_ZenithAngle_Acceleration
# 683 : DriveControl_Status_TrackingMax_ZenithAngle_Deceleration
# 684 : DriveControl_Status_TrackingMax_ZenithAngle_Jerk
# 685 : DriveControl_Status_TrackingMax_ZenithAngle_Position
# 686 : DriveControl_Status_TrackingMax_ZenithAngle_Speed
# 687 : DriveControl_Status_Tracking_Azimuth_Torque_Limit_Perc
# 688 : DriveControl_Status_Tracking_ZenithAngle_Torque_Limit_Perc
# 689 : DriveControl_Test
# 690 : DriveControl_Track_Altitude
# 691 : DriveControl_Track_Azimuth
# 692 : DriveControl_Track_Duration
# 693 : DriveControl_Track_EndTime
# 694 : DriveControl_Track_RemainingTime
# 695 : DriveControl_Track_Time
# 696 : DriveControl_ZenithAngle_Offset
# 697 : DriveControl__ControlLoopTimeStamp
# 698 : DriveControl__Enable_Heart_Beat
# 699 : DriveControl__Error_Heart_Beat
# 700 : DriveControl__Heart_Beat
# 701 : DriveControl__Heart_Beat_TimeOut
# 702 : ECC_FSM_state
# 703 : ECC_FSM_transition
# 704 : ECC_Monitoring_AirValve_AirRegulationStatus
# 705 : ECC_Monitoring_AirValve_AirValveError
# 706 : ECC_Monitoring_AirValve_AirValveStatus
# 707 : ECC_Monitoring_Alarm_Status_Alarm_Back_Door
# 708 : ECC_Monitoring_Alarm_Status_Alarm_Caco_HeartBeat
# 709 : ECC_Monitoring_Alarm_Status_Alarm_ChillerHeating
# 710 : ECC_Monitoring_Alarm_Status_Alarm_Current_24V_PSU1
# 711 : ECC_Monitoring_Alarm_Status_Alarm_Current_24V_PSU2
# 712 : ECC_Monitoring_Alarm_Status_Alarm_Flowmeter
# 713 : ECC_Monitoring_Alarm_Status_Alarm_Front_Door
# 714 : ECC_Monitoring_Alarm_Status_Alarm_General_current
# 715 : ECC_Monitoring_Alarm_Status_Alarm_Humidity
# 716 : ECC_Monitoring_Alarm_Status_Alarm_IR
# 717 : ECC_Monitoring_Alarm_Status_Alarm_Light
# 718 : ECC_Monitoring_Alarm_Status_Alarm_PDB
# 719 : ECC_Monitoring_Alarm_Status_Alarm_Pressure
# 720 : ECC_Monitoring_Alarm_Status_Alarm_Smoke
# 721 : ECC_Monitoring_Alarm_Status_Alarm_Spare
# 722 : ECC_Monitoring_Alarm_Status_Alarm_Temperature
# 723 : ECC_Monitoring_Alarm_Status_Alarm_WaterLeak
# 724 : ECC_Monitoring_Alarm_Status_Alarm_WaterPressure
# 725 : ECC_Monitoring_Alarm_Status_WarningFanTachymeter
# 726 : ECC_Monitoring_Alarm_Status_Warning_Temperature
# 727 : ECC_Monitoring_Chiller_CommunicationStatus
# 728 : ECC_Monitoring_Chiller_ECC_RegulationStatus
# 729 : ECC_Monitoring_Chiller_ECC_RegulationSwitchCode
# 730 : ECC_Monitoring_Chiller_ECC_RegulationSwitchString
# 731 : ECC_Monitoring_Chiller_ErrorCode
# 732 : ECC_Monitoring_Chiller_FSMState
# 733 : ECC_Monitoring_Chiller_GeneralStatus
# 734 : ECC_Monitoring_Chiller_HP_LP_Pressure
# 735 : ECC_Monitoring_Chiller_Heating_Cooling_Countdown
# 736 : ECC_Monitoring_Chiller_RelayStatus
# 737 : ECC_Monitoring_Chiller_TemperatureAmbiant
# 738 : ECC_Monitoring_Chiller_TemperatureEvaporatorWater
# 739 : ECC_Monitoring_Chiller_TemperatureTankWater
# 740 : ECC_Monitoring_CommissioningMode
# 741 : ECC_Monitoring_CoolingValve_CoolingRegulationStatus
# 742 : ECC_Monitoring_CoolingValve_CoolingValveError
# 743 : ECC_Monitoring_CoolingValve_CoolingValveStatus
# 744 : ECC_Monitoring_Debug_ECC_ECC_Program_Version
# 745 : ECC_Monitoring_ECC_Error_ErrorDescription
# 746 : ECC_Monitoring_ECC_Error_ErrorNumber
# 747 : ECC_Monitoring_ECC_Error_ErrorResolution
# 748 : ECC_Monitoring_Front_fans_FanTachymeterError_
# 749 : ECC_Monitoring_Front_fans_FanTachymeter_
# 750 : ECC_Monitoring_Front_fans_GeneralStatus
# 751 : ECC_Monitoring_IntelligentRelay_Current
# 752 : ECC_Monitoring_IntelligentRelay_Status
# 753 : ECC_Monitoring_IntelligentRelay_StatusMonitoring
# 754 : ECC_Monitoring_IntelligentRelay_Voltage
# 755 : ECC_Monitoring_LEDPositions_GeneralStatus
# 756 : ECC_Monitoring_LEDPositions_Led_
# 757 : ECC_Monitoring_PDB_ActiveEnergy400V
# 758 : ECC_Monitoring_PDB_ApparentEnergy400V
# 759 : ECC_Monitoring_PDB_Cosinus400V
# 760 : ECC_Monitoring_PDB_CurrentSensors_CurrentSupply230V
# 761 : ECC_Monitoring_PDB_CurrentSensors_CurrentSupply400V_L
# 762 : ECC_Monitoring_PDB_Frequency400V
# 763 : ECC_Monitoring_PDB_PDBStatus_Led_Control
# 764 : ECC_Monitoring_PDB_PDBStatus_OF_MOTOR_400V
# 765 : ECC_Monitoring_PDB_PDBStatus_OF_MOTOR_AUX_400V
# 766 : ECC_Monitoring_PDB_PDBStatus_OF_MOTOR_AUX_SAI
# 767 : ECC_Monitoring_PDB_PDBStatus_OF_MOTOR_SAI
# 768 : ECC_Monitoring_PDB_PDBStatus_SD_MOTOR_400V
# 769 : ECC_Monitoring_PDB_PDBStatus_SD_MOTOR_SAI
# 770 : ECC_Monitoring_PDB_PDBStatus_StateBreaker
# 771 : ECC_Monitoring_PDB_PDBStatus_StateEmergencyStop
# 772 : ECC_Monitoring_PDB_PDBStatus_SwitchStatus_General230V
# 773 : ECC_Monitoring_PDB_PDBStatus_SwitchStatus_General400V
# 774 : ECC_Monitoring_PDB_PDBStatus_SwitchStatus_fanFront
# 775 : ECC_Monitoring_PDB_PDBStatus_SwitchStatus_fanRear
# 776 : ECC_Monitoring_PDB_PDBStatus_SwitchStatus_line400V
# 777 : ECC_Monitoring_PDB_PDBStatus_SwitchStatus_shutter
# 778 : ECC_Monitoring_PDB_PDBStatus_SwitchStatus_switch1
# 779 : ECC_Monitoring_PDB_PDBStatus_SwitchStatus_switch2
# 780 : ECC_Monitoring_PDB_PDBStatus_TriggerPowerSupply
# 781 : ECC_Monitoring_PDB_PhaseToPhase400VSensors_PhaseToPhase400V_L
# 782 : ECC_Monitoring_PDB_Power_ActivePower400V_L
# 783 : ECC_Monitoring_PDB_Power_ActivePowerUPS
# 784 : ECC_Monitoring_PDB_Power_ApparentPower400V_L
# 785 : ECC_Monitoring_PDB_Power_ApparentPowerUPS
# 786 : ECC_Monitoring_PDB_Power_PowerFactorUPS
# 787 : ECC_Monitoring_PDB_Power_PowerFactor_L
# 788 : ECC_Monitoring_PDB_Power_ReactiveCapacitivePowerUPS
# 789 : ECC_Monitoring_PDB_Power_ReactiveInductivePowerUPS
# 790 : ECC_Monitoring_PDB_Power_ReactivePower400V_L
# 791 : ECC_Monitoring_PDB_Power_ReactivePowerUPS
# 792 : ECC_Monitoring_PDB_Temperature
# 793 : ECC_Monitoring_PDB_VoltageSensors_VoltageSupply230V
# 794 : ECC_Monitoring_PDB_VoltageSensors_VoltageSupply400V_L
# 795 : ECC_Monitoring_PSB_CurrentSupply24VPSB
# 796 : ECC_Monitoring_PSB_PowerSupplyPSB1_
# 797 : ECC_Monitoring_PSB_PowerSupplyPSB2_
# 798 : ECC_Monitoring_Rear_fans_GeneralStatus
# 799 : ECC_Monitoring_Sensors_AirDifferentialPressureSensors_AirDifferentialPressureSensor
# 800 : ECC_Monitoring_Sensors_AirDifferentialPressureSensors_AirDifferentialPresureSensor
# 801 : ECC_Monitoring_Sensors_Doors_BackDoorsOpen
# 802 : ECC_Monitoring_Sensors_Doors_BackDoorsSensor
# 803 : ECC_Monitoring_Sensors_Doors_FrontDoorsOpen
# 804 : ECC_Monitoring_Sensors_Flowmeters_FlowmeterSensor
# 805 : ECC_Monitoring_Sensors_HumiditySensors_HumiditySensor
# 806 : ECC_Monitoring_Sensors_HumiditySensors_TempSensor
# 807 : ECC_Monitoring_Sensors_LightSensors_Light_
# 808 : ECC_Monitoring_Sensors_SmokeSensors_SmokeSensor
# 809 : ECC_Monitoring_Sensors_TemperatureSensors_TemperatureSensor_
# 810 : ECC_Monitoring_Sensors_WaterLeakSensors_WaterLeakSensor
# 811 : ECC_Monitoring_Sensors_WaterPressureSensors_WaterPressureSensor_
# 812 : ECC_Monitoring_Sensors_WaterPressureSensors_WaterPresureSensor_
# 813 : ECC_Monitoring_Shutter_Down_Contactor
# 814 : ECC_Monitoring_Shutter_Error
# 815 : ECC_Monitoring_Shutter_ErrorInfo
# 816 : ECC_Monitoring_Shutter_GeneralStatus
# 817 : ECC_Monitoring_Shutter_KeyStatus
# 818 : ECC_Monitoring_Shutter_PLC_Shutter_PLC_AngularSensor
# 819 : ECC_Monitoring_Shutter_PLC_Shutter_PLC_CloseButton
# 820 : ECC_Monitoring_Shutter_PLC_Shutter_PLC_CommunicationStatus
# 821 : ECC_Monitoring_Shutter_PLC_Shutter_PLC_EmergencyButton
# 822 : ECC_Monitoring_Shutter_PLC_Shutter_PLC_ErrorType
# 823 : ECC_Monitoring_Shutter_PLC_Shutter_PLC_OpenButton
# 824 : ECC_Monitoring_Shutter_PLC_Shutter_PLC_Reserved
# 825 : ECC_Monitoring_Shutter_PLC_Shutter_PLC_SelectAutoManual
# 826 : ECC_Monitoring_Shutter_PLC_Shutter_PLC_Status
# 827 : ECC_Monitoring_Shutter_PLC_Shutter_PLC_WireSensor
# 828 : ECC_Monitoring_Shutter_Up_Contactor
# 829 : ECC_Monitoring_Spares_Analog_A0_
# 830 : ECC_Monitoring_Spares_Analog_AI_
# 831 : ECC_Monitoring_Spares_Digital_D0_
# 832 : ECC_Monitoring_Spares_Digital_DI_
# 833 : ECC_Monitoring_Spares_Heater
# 834 : ECC_Monitoring_Transition_Countdown
# 835 : ECC_Monitoring_Transition_Information
# 836 : ECC_Monitoring_WhiteTarget_Horizontal_BottomLeft
# 837 : ECC_Monitoring_WhiteTarget_Horizontal_BottomRight
# 838 : ECC_Monitoring_WhiteTarget_Horizontal_HorizontalEncoder
# 839 : ECC_Monitoring_WhiteTarget_Horizontal_TopLeft
# 840 : ECC_Monitoring_WhiteTarget_Horizontal_TopRight
# 841 : ECC_Monitoring_WhiteTarget_Vertical_Bottom
# 842 : ECC_Monitoring_WhiteTarget_Vertical_Top
# 843 : ECC_Monitoring_WhiteTarget_Vertical_VerticalEncoder
# 844 : ECC__ControlLoopTimeStamp
# 845 : SecurityBrokerControl_Power_CameraUPS_P
# 846 : SecurityBrokerControl_WAGO_ATS_PLC_PRG_ATSPLC2_ATS_GEN
# 847 : SecurityBrokerControl_WAGO_ATS_PLC_PRG_ATSPLC2_ATS_IT
# 848 : SecurityBrokerControl_WAGO_ATS_PLC_PRG_ATSPLC2_ATS_SPR
# 849 : SecurityBrokerControl_WAGO_ATS_PLC_PRG_ATSPLC2_ATS_UC1
# 850 : SecurityBrokerControl_WAGO_ATS_PLC_PRG_ATSPLC2_ATS_UTL
# 851 : SecurityBrokerControl_WAGO_ATS_PLC_PRG_GATEWAY_ATS_GENPOW
# 852 : SecurityBrokerControl_WAGO_ATS_PLC_PRG_GATEWAY_ATS_SYSALM
# 853 : SecurityBrokerControl_WAGO_ATS_PLC_PRG_GATEWAY_ATS_UTLPOW
# 854 : SecurityBrokerControl_WAGO_ATS_PLC_PRG_GenGATEWAY_GEN_FUEL
# 855 : SecurityBrokerControl_WAGO_ATS_PLC_PRG_GenGATEWAY_GEN_SYSALM
# 856 : SecurityBrokerControl_WAGO_ATS_PLC_PRG_OUT_ATS_AVL
# 857 : SecurityBrokerControl_WAGO_ATS_PLC_PRG_OUT_GEN_AVL
# 858 : SecurityBrokerControl_WAGO_UC_PLC_PRG_ATS_PLC_OUT_GRID
# 859 : SecurityBrokerControl_WAGO_UC_PLC_PRG_FW_FW1_AVLENE
# 860 : SecurityBrokerControl_WAGO_UC_PLC_PRG_FW_FW1_SYSALM
# 861 : SecurityBrokerControl_WAGO_UC_PLC_PRG_FW_FW2_AVLENE
# 862 : SecurityBrokerControl_WAGO_UC_PLC_PRG_FW_FW2_SYSALM
# 863 : SecurityBrokerControl_WAGO_UC_PLC_PRG_FW_OUT_FW1
# 864 : SecurityBrokerControl_WAGO_UC_PLC_PRG_FW_OUT_FW2
# 865 : SecurityBrokerControl_WAGO_UC_PLC_PRG_OUT_OUT_DRIVE_GRB
# 866 : SecurityBrokerControl_WAGO_UC_PLC_PRG_OUT_OUT_DRIVE_NORMAL
# 867 : SecurityBrokerControl_WAGO_UC_PLC_PRG_UCPLC_OUT_UPS
# 868 : SecurityBrokerControl_WAGO_UC_PLC_PRG_UCPLC_UPS_HUMI
# 869 : SecurityBrokerControl_WAGO_UC_PLC_PRG_UCPLC_UPS_TEMP
# 870 : SecurityBrokerControl_WS_Monitoring_Absolute_Air_Pressure
# 871 : SecurityBrokerControl_WS_Monitoring_Absolute_Humidity
# 872 : SecurityBrokerControl_WS_Monitoring_Air_Temperature
# 873 : SecurityBrokerControl_WS_Monitoring_Azimuth_Position_Sun
# 874 : SecurityBrokerControl_WS_Monitoring_Brightness
# 875 : SecurityBrokerControl_WS_Monitoring_Compass_Direction
# 876 : SecurityBrokerControl_WS_Monitoring_Dew_Point_Temperature
# 877 : SecurityBrokerControl_WS_Monitoring_Elevation_Position_Sun
# 878 : SecurityBrokerControl_WS_Monitoring_GPS_Operating
# 879 : SecurityBrokerControl_WS_Monitoring_Global_Radiation
# 880 : SecurityBrokerControl_WS_Monitoring_Max_Wind_Speed
# 881 : SecurityBrokerControl_WS_Monitoring_Mean_Wind_Speed
# 882 : SecurityBrokerControl_WS_Monitoring_Precipitation
# 883 : SecurityBrokerControl_WS_Monitoring_Precipitation_Difference
# 884 : SecurityBrokerControl_WS_Monitoring_Precipitation_Intensity
# 885 : SecurityBrokerControl_WS_Monitoring_Precipitation_Type
# 886 : SecurityBrokerControl_WS_Monitoring_Refresh
# 887 : SecurityBrokerControl_WS_Monitoring_Relative_Air_Pressure
# 888 : SecurityBrokerControl_WS_Monitoring_Relative_Humidity
# 889 : SecurityBrokerControl_WS_Monitoring_Run_Time
# 890 : SecurityBrokerControl_WS_Monitoring_Twilight
# 891 : SecurityBrokerControl_WS_Monitoring_UTC_Time_High
# 892 : SecurityBrokerControl_WS_Monitoring_UTC_Time_Low
# 893 : SecurityBrokerControl_WS_Monitoring_UV_Index
# 894 : SecurityBrokerControl_WS_Monitoring_Wind_Direction
# 895 : SecurityBrokerControl_WS_Monitoring_Wind_Direction_Compass
# 896 : SecurityBrokerControl_WS_Monitoring_Wind_Speed
# 897 : SecurityBrokerControl_WS_Status_Brightness_Sensor
# 898 : SecurityBrokerControl_WS_Status_Device_Status_high
# 899 : SecurityBrokerControl_WS_Status_Device_Status_low
# 900 : SecurityBrokerControl_WS_Status_Humidity_Sensor
# 901 : SecurityBrokerControl_WS_Status_ModbusConnection
# 902 : SecurityBrokerControl_WS_Status_ModbusConnection_Sensor
# 903 : SecurityBrokerControl_WS_Status_Precipitation_Sensor
# 904 : SecurityBrokerControl_WS_Status_Pressure_Sensor
# 905 : SecurityBrokerControl_WS_Status_Radiation_Sensor
# 906 : SecurityBrokerControl_WS_Status_Temperature_Sensor
# 907 : SecurityBrokerControl_WS_Status_UV_Index_Sensor
# 908 : SecurityBrokerControl_WS_Status_Wifi_Sensor
# 909 : SecurityBrokerControl_WS_Status_Wind_Sensor
# 910 : TIB_Alarm_AlarmVector
# 911 : TIB_Alarm_AlmostFull
# 912 : TIB_Alarm_BufferFull
# 913 : TIB_Alarm_PPSFailure
# 914 : TIB_Alarm_ReadError
# 915 : TIB_Alarm_Unlocked
# 916 : TIB_Alarm_WriteError
# 917 : TIB_ArmedDelayStereo
# 918 : TIB_BUSY_BusyBP
# 919 : TIB_BUSY_DisableBusy
# 920 : TIB_BUSY_ExtraDelayBusy
# 921 : TIB_BUSY_InternalBusy
# 922 : TIB_Clock_select
# 923 : TIB_CoincidenceWindow
# 924 : TIB_ConnectionStatus
# 925 : TIB_DACOptical_Neighbour
# 926 : TIB_DebugVector
# 927 : TIB_Delays_CompoundDelay
# 928 : TIB_Delays_Delay
# 929 : TIB_Delays_DelayLocal
# 930 : TIB_EventsInRun_BUSYRun
# 931 : TIB_EventsInRun_CalibrationRun
# 932 : TIB_EventsInRun_CameraRun
# 933 : TIB_EventsInRun_CollectedRun
# 934 : TIB_EventsInRun_In1Run
# 935 : TIB_EventsInRun_In2Run
# 936 : TIB_EventsInRun_In3Run
# 937 : TIB_EventsInRun_In4Run
# 938 : TIB_EventsInRun_LocalRun
# 939 : TIB_EventsInRun_PPSRun
# 940 : TIB_EventsInRun_PedestalRun
# 941 : TIB_EventsInRun_SlowControlRun
# 942 : TIB_EventsInRun_SoftrigRun
# 943 : TIB_EventsInRun_SpheRun
# 944 : TIB_EventsInRun_StereoRun
# 945 : TIB_ExternalDelay_ExternalDelayCalibration
# 946 : TIB_ExternalDelay_ExternalDelayLocal
# 947 : TIB_ExternalDelay_ExternalDelaySphe
# 948 : TIB_InputsEnable_Input
# 949 : TIB_InputsEnable_InputLocal
# 950 : TIB_InputsEnable_InputMask
# 951 : TIB_OF_delayMeasure_Launch_OF_measure
# 952 : TIB_OF_delayMeasure_OF_delay
# 953 : TIB_OF_delayMeasure_Passive_OF_resend
# 954 : TIB_Pedestal_AnalogPedestalEnable
# 955 : TIB_Pedestal_AnalogPedestalThreshold
# 956 : TIB_Pedestal_DigitalPedestalEnable
# 957 : TIB_Pedestal_DigitalPedestalSeed
# 958 : TIB_Pedestal_DigitalPedestal_config_Rate
# 959 : TIB_Pedestal_Fake_trig_enable
# 960 : TIB_Pedestal_PeriodicPedestalEnable
# 961 : TIB_Pedestal_PeriodicPedestalFrequency
# 962 : TIB_Rates_BUSYRate
# 963 : TIB_Rates_CalibrationRate
# 964 : TIB_Rates_CameraRate
# 965 : TIB_Rates_CollectedRate
# 966 : TIB_Rates_In1Rate
# 967 : TIB_Rates_In2Rate
# 968 : TIB_Rates_In3Rate
# 969 : TIB_Rates_In4Rate
# 970 : TIB_Rates_In5Rate
# 971 : TIB_Rates_In6Rate
# 972 : TIB_Rates_In7Rate
# 973 : TIB_Rates_In8Rate
# 974 : TIB_Rates_LocalRate
# 975 : TIB_Rates_PedestalRate
# 976 : TIB_Rates_SoftrigRate
# 977 : TIB_Rates_SpheRate
# 978 : TIB_Rates_StereoRate
# 979 : TIB_ReadState
# 980 : TIB_RedundantCables_RedundantCable
# 981 : TIB_StereoCondition
# 982 : TIB_TIB_TXclient_alive
# 983 : TIB_Temperature
# 984 : TIB_Throttler_DisableThrottler
# 985 : TIB_Throttler_MaxTriggers1ms
# 986 : TIB_Throttler_MaxTriggers50us
# 987 : TIB_TriggerMode_CalibrationEnable
# 988 : TIB_TriggerMode_ModeMask
# 989 : TIB_TriggerMode_MonoEnable
# 990 : TIB_TriggerMode_PedestalEnable
# 991 : TIB_TriggerMode_SlowControlEnable
# 992 : TIB_TriggerMode_SoftwareTrigEnable
# 993 : TIB_TriggerMode_SpheEnable
# 994 : TIB_TriggerMode_StereoEnable
# 995 : TIB__ControlLoopTimeStamp
# 996 : exports_FSM_error_error_message
# 997 : exports_FSM_state
# 998 : exports__ControlLoopTimeStamp
# 999 : exports_actions_calibrations_external_delay_end_time
# 1000 : exports_actions_calibrations_external_delay_start_time
# 1001 : exports_actions_calibrations_external_delay_status
# 1002 : exports_actions_calibrations_external_delay_values
# 1003 : exports_actions_calibrations_external_delay_xtra_information
# 1004 : exports_actions_calibrations_external_gain_end_time
# 1005 : exports_actions_calibrations_external_gain_start_time
# 1006 : exports_actions_calibrations_external_gain_status
# 1007 : exports_actions_calibrations_external_gain_values
# 1008 : exports_actions_calibrations_external_gain_xtra_information
# 1009 : exports_actions_calibrations_internal_delay_end_time
# 1010 : exports_actions_calibrations_internal_delay_start_time
# 1011 : exports_actions_calibrations_internal_delay_status
# 1012 : exports_actions_calibrations_internal_delay_values
# 1013 : exports_actions_calibrations_internal_delay_xtra_information
# 1014 : exports_actions_calibrations_internal_gain_end_time
# 1015 : exports_actions_calibrations_internal_gain_start_time
# 1016 : exports_actions_calibrations_internal_gain_status
# 1017 : exports_actions_calibrations_internal_gain_values
# 1018 : exports_actions_calibrations_internal_gain_xtra_information
# 1019 : exports_actions_calibrations_pixel_DTN0
# 1020 : exports_actions_calibrations_pixel_DTl0
# 1021 : exports_actions_calibrations_pixels_DTL0
# 1022 : exports_actions_calibrations_pixels_DTN
# 1023 : exports_actions_scans_scan_ipr_begin
# 1024 : exports_actions_scans_scan_ipr_end
# 1025 : exports_actions_scans_scan_ipr_end_time
# 1026 : exports_actions_scans_scan_ipr_start_time
# 1027 : exports_actions_scans_scan_ipr_status
# 1028 : exports_actions_scans_scan_ipr_steps
# 1029 : exports_actions_scans_scan_ipr_values_values
# 1030 : exports_actions_scans_scan_l1_begin
# 1031 : exports_actions_scans_scan_l1_end
# 1032 : exports_actions_scans_scan_l1_end_time
# 1033 : exports_actions_scans_scan_l1_start_time
# 1034 : exports_actions_scans_scan_l1_status
# 1035 : exports_actions_scans_scan_l1_steps
# 1036 : exports_actions_scans_scan_l1_values_values
# 1037 : exports_monitoring_clusco_busy_state
# 1038 : exports_monitoring_clusco_central_bp
# 1039 : exports_monitoring_clusco_date_built
# 1040 : exports_monitoring_clusco_error
# 1041 : exports_monitoring_clusco_hv_on
# 1042 : exports_monitoring_clusco_l0_hot
# 1043 : exports_monitoring_clusco_l0_rate_control
# 1044 : exports_monitoring_clusco_l0_rate_max
# 1045 : exports_monitoring_clusco_l1_rate_control
# 1046 : exports_monitoring_clusco_l1_rate_max
# 1047 : exports_monitoring_clusco_l1_rate_target
# 1048 : exports_monitoring_clusco_last_report_msecond
# 1049 : exports_monitoring_clusco_last_report_second
# 1050 : exports_monitoring_clusco_major_ver
# 1051 : exports_monitoring_clusco_major_version
# 1052 : exports_monitoring_clusco_mean_dc
# 1053 : exports_monitoring_clusco_mean_dc_healthy
# 1054 : exports_monitoring_clusco_minor_ver
# 1055 : exports_monitoring_clusco_minor_version
# 1056 : exports_monitoring_clusco_monitoring_sleep
# 1057 : exports_monitoring_clusco_nb_hv_reduced
# 1058 : exports_monitoring_clusco_read_once_msecond
# 1059 : exports_monitoring_clusco_read_once_second
# 1060 : exports_monitoring_clusco_read_rarely_msecond
# 1061 : exports_monitoring_clusco_read_rarely_second
# 1062 : exports_monitoring_clusco_sub_ver
# 1063 : exports_monitoring_clusco_sub_version
# 1064 : exports_monitoring_clusco_time_built
# 1065 : exports_monitoring_clusco_zenith
# 1066 : exports_monitoring_hardware_values_cluster_backplane_firmware
# 1067 : exports_monitoring_hardware_values_cluster_backplane_flag
# 1068 : exports_monitoring_hardware_values_cluster_backplane_reg65
# 1069 : exports_monitoring_hardware_values_cluster_backplane_scalar
# 1070 : exports_monitoring_hardware_values_cluster_backplane_tdc_delta
# 1071 : exports_monitoring_hardware_values_cluster_backplane_temperature
# 1072 : exports_monitoring_hardware_values_cluster_bp_scalar
# 1073 : exports_monitoring_hardware_values_cluster_bp_tdc_delta
# 1074 : exports_monitoring_hardware_values_cluster_bp_temperature
# 1075 : exports_monitoring_hardware_values_cluster_busy
# 1076 : exports_monitoring_hardware_values_cluster_dragon_busy
# 1077 : exports_monitoring_hardware_values_cluster_dragon_drs4_humidity
# 1078 : exports_monitoring_hardware_values_cluster_dragon_drs4_temperature
# 1079 : exports_monitoring_hardware_values_cluster_dragon_drs_cascade_channels
# 1080 : exports_monitoring_hardware_values_cluster_dragon_drs_mode
# 1081 : exports_monitoring_hardware_values_cluster_dragon_drs_offset
# 1082 : exports_monitoring_hardware_values_cluster_dragon_drs_read_depth
# 1083 : exports_monitoring_hardware_values_cluster_dragon_drs_sampling_frequency
# 1084 : exports_monitoring_hardware_values_cluster_dragon_drs_trigger_delay
# 1085 : exports_monitoring_hardware_values_cluster_dragon_drs_trigger_selection
# 1086 : exports_monitoring_hardware_values_cluster_dragon_firmware
# 1087 : exports_monitoring_hardware_values_cluster_dragon_flag
# 1088 : exports_monitoring_hardware_values_cluster_dragon_l0_rate_window
# 1089 : exports_monitoring_hardware_values_cluster_dragon_l1_rate_window
# 1090 : exports_monitoring_hardware_values_cluster_dragon_mac_address
# 1091 : exports_monitoring_hardware_values_cluster_dragon_reg_temperature
# 1092 : exports_monitoring_hardware_values_cluster_dragon_six_v
# 1093 : exports_monitoring_hardware_values_cluster_dragon_tp_injection
# 1094 : exports_monitoring_hardware_values_cluster_dragon_tp_rate
# 1095 : exports_monitoring_hardware_values_cluster_enabled
# 1096 : exports_monitoring_hardware_values_cluster_error
# 1097 : exports_monitoring_hardware_values_cluster_l0_majority
# 1098 : exports_monitoring_hardware_values_cluster_l0_sate
# 1099 : exports_monitoring_hardware_values_cluster_l0_sum
# 1100 : exports_monitoring_hardware_values_cluster_l1_adder
# 1101 : exports_monitoring_hardware_values_cluster_l1_dac_threshold_default
# 1102 : exports_monitoring_hardware_values_cluster_l1_dac_threshold_set
# 1103 : exports_monitoring_hardware_values_cluster_l1_extern_rate
# 1104 : exports_monitoring_hardware_values_cluster_l1_rate
# 1105 : exports_monitoring_hardware_values_cluster_l1_rate_low
# 1106 : exports_monitoring_hardware_values_cluster_l1_state
# 1107 : exports_monitoring_hardware_values_cluster_majority_enabled
# 1108 : exports_monitoring_hardware_values_cluster_number
# 1109 : exports_monitoring_hardware_values_cluster_port
# 1110 : exports_monitoring_hardware_values_cluster_scb_flag
# 1111 : exports_monitoring_hardware_values_cluster_scb_humidity
# 1112 : exports_monitoring_hardware_values_cluster_scb_hw_version
# 1113 : exports_monitoring_hardware_values_cluster_scb_id_code
# 1114 : exports_monitoring_hardware_values_cluster_scb_pmask
# 1115 : exports_monitoring_hardware_values_cluster_scb_pmt_current
# 1116 : exports_monitoring_hardware_values_cluster_scb_sw_version
# 1117 : exports_monitoring_hardware_values_cluster_scb_temperature
# 1118 : exports_monitoring_hardware_values_cluster_scb_testpulse_enabled
# 1119 : exports_monitoring_hardware_values_cluster_scb_uid
# 1120 : exports_monitoring_hardware_values_cluster_state
# 1121 : exports_monitoring_hardware_values_cluster_sum_enabled
# 1122 : exports_monitoring_hardware_values_cluster_sw_version
# 1123 : exports_monitoring_hardware_values_cluster_tp_rate
# 1124 : exports_monitoring_hardware_values_pixel_AN_current
# 1125 : exports_monitoring_hardware_values_pixel_clipping_bias
# 1126 : exports_monitoring_hardware_values_pixel_clipping_sel
# 1127 : exports_monitoring_hardware_values_pixel_delay
# 1128 : exports_monitoring_hardware_values_pixel_dt
# 1129 : exports_monitoring_hardware_values_pixel_enabled
# 1130 : exports_monitoring_hardware_values_pixel_error
# 1131 : exports_monitoring_hardware_values_pixel_gain
# 1132 : exports_monitoring_hardware_values_pixel_l0_asic_main_register
# 1133 : exports_monitoring_hardware_values_pixel_l0_clipping_bias
# 1134 : exports_monitoring_hardware_values_pixel_l0_clipping_sel
# 1135 : exports_monitoring_hardware_values_pixel_l0_delay
# 1136 : exports_monitoring_hardware_values_pixel_l0_dt
# 1137 : exports_monitoring_hardware_values_pixel_l0_gain
# 1138 : exports_monitoring_hardware_values_pixel_l0_ipr
# 1139 : exports_monitoring_hardware_values_pixel_l0_on
# 1140 : exports_monitoring_hardware_values_pixel_l0_rate
# 1141 : exports_monitoring_hardware_values_pixel_l0_threshold_register
# 1142 : exports_monitoring_hardware_values_pixel_pixel_error
# 1143 : exports_monitoring_hardware_values_pixel_scb_amplifier_id_code
# 1144 : exports_monitoring_hardware_values_pixel_scb_an_current
# 1145 : exports_monitoring_hardware_values_pixel_scb_hotcold
# 1146 : exports_monitoring_hardware_values_pixel_scb_hv_default
# 1147 : exports_monitoring_hardware_values_pixel_scb_hv_monitored
# 1148 : exports_monitoring_hardware_values_pixel_scb_hv_set
# 1149 : exports_monitoring_hardware_values_pixel_scb_pcode
# 1150 : exports_monitoring_hardware_values_pixel_scb_pixel_temperature
# 1151 : exports_monitoring_hardware_values_pixel_scb_temperature
# 1152 : exports_monitoring_hardware_values_pixel_scb_tp_boost
# 1153 : exports_monitoring_hardware_values_pixel_scb_tp_gain
# 1154 : exports_monitoring_hardware_values_pixel_tp_boost
# 1155 : exports_monitoring_number_of_cluster
# 1156 : exports_monitoring_number_of_clusters
# 1157 : exports_monitoring_state
# 1158 : exports_monitoring_version

# %% [markdown]
# #### CaCo databases and collections:

# %%
# client_caco = pymongo.MongoClient("localhost:27018")

# all_databases = np.sort(client_caco.list_database_names())

# print(f"--- {'':^40s} ---")
# print(f"--- {'Available CaCo databases and collections':^40s} ---")
# print(f"--- {'':^40s} ---")
# for database in all_databases:
#     print(f"\n--- {f'Database - {database}':^40s} ---")
    
#     all_collections = np.sort(client_caco[database].list_collection_names())
#     for i, collection in enumerate(all_collections):
#         print(f"{i:4d} : {collection}")

# %% [markdown]
# #### All properties from CaCo database:

# %%
# Selecting CaCo database
caco_db = client_caco.CACO

dict_caco_names = {}
all_collections = np.sort(caco_db.list_collection_names())
for coll_name in all_collections:
    coll = caco_db[coll_name]
    if coll not in ["STATE", "RUN_INFORMATION"] and "week" in coll_name:
    
        print(f"\n--- {f'Collection - {coll_name}':^40s} ---")
        names = coll.distinct("name")
        
        dict_caco_names[coll_name.replace("week", "min")] = names
        for i,n in enumerate(names):
            print(f"{i:4.0f} : {n}")
# Out:
# ---          Collection - CBOX_week          ---
#    0 : CBOX_DewPoint
#    1 : CBOX_Error_InterCalibration_Mean
#    2 : CBOX_FSM_state
#    3 : CBOX_Humidity
#    4 : CBOX_InterCalibration_Mean
#    5 : CBOX_LaserStatus
#    6 : CBOX_LaserTrigParameters1
#    7 : CBOX_LaserTrigParameters2
#    8 : CBOX_Pressure
#    9 : CBOX_Temperature
#   10 : CBOX_WheelPosition1
#   11 : CBOX_WheelPosition2
#
# ---         Collection - CLUSCO_week         ---
#    0 : backplane_error_flag
#    1 : backplane_firmware
#    2 : backplane_temperature
#    3 : clusco_busy_state
#    4 : clusco_hv_on
#    5 : clusco_l0_hot
#    6 : clusco_l0_rate_control
#    7 : clusco_l0_rate_max
#    8 : clusco_l1_rate_control
#    9 : clusco_l1_rate_max
#   10 : clusco_l1_rate_target
#   11 : clusco_mean_dc
#   12 : clusco_mean_dc_healthy
#   13 : clusco_nb_hv_reduced
#   14 : clusco_zenith
#   15 : cluster_status
#   16 : dragon_busy
#   17 : dragon_drs_cascade_channels
#   18 : dragon_drs_read_depth
#   19 : dragon_drs_sampling_frequency
#   20 : dragon_drs_trigger_selection
#   21 : dragon_error_flag
#   22 : dragon_firmware
#   23 : dragon_l0_rate_window
#   24 : dragon_l1_rate_window
#   25 : dragon_mac_address
#   26 : l0_majority
#   27 : l0_pixel_asic_main_register
#   28 : l0_pixel_clipping_bias
#   29 : l0_pixel_clipping_sel
#   30 : l0_pixel_delay
#   31 : l0_pixel_dt
#   32 : l0_pixel_gain
#   33 : l0_pixel_ipr
#   34 : l0_pixel_on
#   35 : l0_sum
#   36 : l1_adder
#   37 : l1_dac_threshold_default
#   38 : l1_dac_threshold_set
#   39 : l1_extern_rate
#   40 : l1_rate
#   41 : l1_state
#   42 : scb_error_flag
#   43 : scb_humidity
#   44 : scb_hw_version
#   45 : scb_id_code
#   46 : scb_p_mask
#   47 : scb_pixel_an_current
#   48 : scb_pixel_hotcold
#   49 : scb_pixel_hv_default
#   50 : scb_pixel_hv_monitored
#   51 : scb_pixel_hv_set
#   52 : scb_pixel_pcode
#   53 : scb_pixel_temperature
#   54 : scb_pmt_current
#   55 : scb_sw_version
#   56 : scb_temperature
#   57 : scb_uid
#
# ---          Collection - ECC_week           ---
#    0 : ECC_FSM_state
#    1 : ECC_FSM_transition
#    2 : ECC_Monitoring_Alarm_Status_Alarm_Back_Door
#    3 : ECC_Monitoring_Alarm_Status_Alarm_Front_Door
#    4 : ECC_Monitoring_Alarm_Status_Alarm_General_current
#    5 : ECC_Monitoring_Alarm_Status_Alarm_Light
#    6 : ECC_Monitoring_Alarm_Status_Alarm_PDB
#    7 : ECC_Monitoring_Alarm_Status_WarningFanTachymeter
#    8 : ECC_Monitoring_CoolingValve_CoolingValveStatus
#    9 : ECC_Monitoring_Debug_ECC_CPU_CPU_idle_usage
#   10 : ECC_Monitoring_Debug_ECC_CPU_CPU_total_usage
#   11 : ECC_Monitoring_Front_fans_FanTachymeterError_01
#   12 : ECC_Monitoring_Front_fans_FanTachymeterError_02
#   13 : ECC_Monitoring_Front_fans_FanTachymeterError_03
#   14 : ECC_Monitoring_Front_fans_FanTachymeterError_04
#   15 : ECC_Monitoring_Front_fans_FanTachymeterError_05
#   16 : ECC_Monitoring_Front_fans_FanTachymeterError_06
#   17 : ECC_Monitoring_Front_fans_FanTachymeter_01
#   18 : ECC_Monitoring_Front_fans_FanTachymeter_02
#   19 : ECC_Monitoring_Front_fans_FanTachymeter_03
#   20 : ECC_Monitoring_Front_fans_FanTachymeter_04
#   21 : ECC_Monitoring_Front_fans_FanTachymeter_05
#   22 : ECC_Monitoring_Front_fans_FanTachymeter_06
#   23 : ECC_Monitoring_IntelligentRelay_Current0
#   24 : ECC_Monitoring_IntelligentRelay_Current1
#   25 : ECC_Monitoring_IntelligentRelay_Current2
#   26 : ECC_Monitoring_IntelligentRelay_Current3
#   27 : ECC_Monitoring_IntelligentRelay_Current4
#   28 : ECC_Monitoring_IntelligentRelay_Current5
#   29 : ECC_Monitoring_IntelligentRelay_Current6
#   30 : ECC_Monitoring_IntelligentRelay_Current7
#   31 : ECC_Monitoring_IntelligentRelay_Status0
#   32 : ECC_Monitoring_IntelligentRelay_Status1
#   33 : ECC_Monitoring_IntelligentRelay_Status2
#   34 : ECC_Monitoring_IntelligentRelay_Status3
#   35 : ECC_Monitoring_IntelligentRelay_Status4
#   36 : ECC_Monitoring_IntelligentRelay_Status5
#   37 : ECC_Monitoring_IntelligentRelay_Status6
#   38 : ECC_Monitoring_IntelligentRelay_Status7
#   39 : ECC_Monitoring_IntelligentRelay_StatusMonitoring0
#   40 : ECC_Monitoring_IntelligentRelay_StatusMonitoring1
#   41 : ECC_Monitoring_IntelligentRelay_StatusMonitoring2
#   42 : ECC_Monitoring_IntelligentRelay_StatusMonitoring3
#   43 : ECC_Monitoring_IntelligentRelay_StatusMonitoring4
#   44 : ECC_Monitoring_IntelligentRelay_StatusMonitoring5
#   45 : ECC_Monitoring_IntelligentRelay_StatusMonitoring6
#   46 : ECC_Monitoring_IntelligentRelay_StatusMonitoring7
#   47 : ECC_Monitoring_IntelligentRelay_Voltage0
#   48 : ECC_Monitoring_IntelligentRelay_Voltage1
#   49 : ECC_Monitoring_IntelligentRelay_Voltage2
#   50 : ECC_Monitoring_IntelligentRelay_Voltage3
#   51 : ECC_Monitoring_IntelligentRelay_Voltage4
#   52 : ECC_Monitoring_IntelligentRelay_Voltage5
#   53 : ECC_Monitoring_IntelligentRelay_Voltage6
#   54 : ECC_Monitoring_IntelligentRelay_Voltage7
#   55 : ECC_Monitoring_LEDPositions_Led_01
#   56 : ECC_Monitoring_LEDPositions_Led_02
#   57 : ECC_Monitoring_LEDPositions_Led_03
#   58 : ECC_Monitoring_LEDPositions_Led_04
#   59 : ECC_Monitoring_LEDPositions_Led_05
#   60 : ECC_Monitoring_LEDPositions_Led_06
#   61 : ECC_Monitoring_LEDPositions_Led_07
#   62 : ECC_Monitoring_LEDPositions_Led_08
#   63 : ECC_Monitoring_LEDPositions_Led_09
#   64 : ECC_Monitoring_LEDPositions_Led_10
#   65 : ECC_Monitoring_LEDPositions_Led_11
#   66 : ECC_Monitoring_LEDPositions_Led_12
#   67 : ECC_Monitoring_LEDPositions_Led_13
#   68 : ECC_Monitoring_LEDPositions_Led_14
#   69 : ECC_Monitoring_LEDPositions_Led_15
#   70 : ECC_Monitoring_LEDPositions_Led_16
#   71 : ECC_Monitoring_LEDPositions_Led_GeneralStatus
#   72 : ECC_Monitoring_PDB_ApparentEnergy400V
#   73 : ECC_Monitoring_PDB_Cosinus400V
#   74 : ECC_Monitoring_PDB_CurrentSensors_CurrentSupply230V
#   75 : ECC_Monitoring_PDB_CurrentSensors_CurrentSupply400V_L1
#   76 : ECC_Monitoring_PDB_CurrentSensors_CurrentSupply400V_L2
#   77 : ECC_Monitoring_PDB_CurrentSensors_CurrentSupply400V_L3
#   78 : ECC_Monitoring_PDB_Frequency400V
#   79 : ECC_Monitoring_PDB_PDBStatus_SwitchStatus_shutter
#   80 : ECC_Monitoring_PDB_PDBStatus_SwitchStatus_switch1
#   81 : ECC_Monitoring_PDB_PDBStatus_SwitchStatus_switch2
#   82 : ECC_Monitoring_PDB_PDBStatus_TriggerPowerSupply
#   83 : ECC_Monitoring_PDB_PhaseToPhase400VSensors_PhaseToPhase400V_L1
#   84 : ECC_Monitoring_PDB_PhaseToPhase400VSensors_PhaseToPhase400V_L2
#   85 : ECC_Monitoring_PDB_PhaseToPhase400VSensors_PhaseToPhase400V_L3
#   86 : ECC_Monitoring_PDB_Power_ActivePower400V_L1
#   87 : ECC_Monitoring_PDB_Power_ActivePower400V_L2
#   88 : ECC_Monitoring_PDB_Power_ActivePower400V_L3
#   89 : ECC_Monitoring_PDB_Power_ActivePowerUPS
#   90 : ECC_Monitoring_PDB_Power_ApparentPower400V_L1
#   91 : ECC_Monitoring_PDB_Power_ApparentPower400V_L2
#   92 : ECC_Monitoring_PDB_Power_ApparentPower400V_L3
#   93 : ECC_Monitoring_PDB_Power_ApparentPowerUPS
#   94 : ECC_Monitoring_PDB_Power_PowerFactorUPS
#   95 : ECC_Monitoring_PDB_Power_PowerFactor_L1
#   96 : ECC_Monitoring_PDB_Power_PowerFactor_L2
#   97 : ECC_Monitoring_PDB_Power_PowerFactor_L3
#   98 : ECC_Monitoring_PDB_Power_ReactiveCapacitivePowerUPS
#   99 : ECC_Monitoring_PDB_Power_ReactiveInductivePowerUPS
#  100 : ECC_Monitoring_PDB_Power_ReactivePowerUPS
#  101 : ECC_Monitoring_PDB_Temperature
#  102 : ECC_Monitoring_PDB_VoltageSensors_VoltageSupply230V
#  103 : ECC_Monitoring_PDB_VoltageSensors_VoltageSupply400V_L1
#  104 : ECC_Monitoring_PDB_VoltageSensors_VoltageSupply400V_L2
#  105 : ECC_Monitoring_PDB_VoltageSensors_VoltageSupply400V_L3
#  106 : ECC_Monitoring_PSB_CurrentSupply24VPSB1
#  107 : ECC_Monitoring_PSB_CurrentSupply24VPSB2
#  108 : ECC_Monitoring_PSB_PowerSupplyPSB1_1
#  109 : ECC_Monitoring_PSB_PowerSupplyPSB1_2
#  110 : ECC_Monitoring_Sensors_AirDifferentialPressureSensors_AirDifferentialPressureSensor
#  111 : ECC_Monitoring_Sensors_Doors_BackDoorsOpen
#  112 : ECC_Monitoring_Sensors_Doors_BackDoorsSensor1
#  113 : ECC_Monitoring_Sensors_Doors_BackDoorsSensor2
#  114 : ECC_Monitoring_Sensors_Doors_FrontDoorsOpen
#  115 : ECC_Monitoring_Sensors_HumiditySensors_HumiditySensor
#  116 : ECC_Monitoring_Sensors_HumiditySensors_TempSensor
#  117 : ECC_Monitoring_Sensors_LightSensors_Light_1
#  118 : ECC_Monitoring_Sensors_LightSensors_Light_2
#  119 : ECC_Monitoring_Sensors_LightSensors_Light_3
#  120 : ECC_Monitoring_Sensors_LightSensors_Light_4
#  121 : ECC_Monitoring_Sensors_TemperatureSensors_TemperatureAverage
#  122 : ECC_Monitoring_Sensors_TemperatureSensors_TemperatureSensor_01
#  123 : ECC_Monitoring_Sensors_TemperatureSensors_TemperatureSensor_02
#  124 : ECC_Monitoring_Sensors_TemperatureSensors_TemperatureSensor_03
#  125 : ECC_Monitoring_Sensors_TemperatureSensors_TemperatureSensor_04
#  126 : ECC_Monitoring_Sensors_TemperatureSensors_TemperatureSensor_05
#  127 : ECC_Monitoring_Sensors_TemperatureSensors_TemperatureSensor_06
#  128 : ECC_Monitoring_Sensors_TemperatureSensors_TemperatureSensor_07
#  129 : ECC_Monitoring_Sensors_TemperatureSensors_TemperatureSensor_08
#  130 : ECC_Monitoring_Sensors_TemperatureSensors_TemperatureSensor_09
#  131 : ECC_Monitoring_Sensors_TemperatureSensors_TemperatureSensor_10
#  132 : ECC_Monitoring_Sensors_TemperatureSensors_TemperatureSensor_11
#  133 : ECC_Monitoring_Sensors_TemperatureSensors_TemperatureSensor_12
#  134 : ECC_Monitoring_Sensors_TemperatureSensors_TemperatureSensor_13
#  135 : ECC_Monitoring_Sensors_TemperatureSensors_TemperatureSensor_14
#  136 : ECC_Monitoring_Sensors_TemperatureSensors_TemperatureSensor_15
#  137 : ECC_Monitoring_Sensors_TemperatureSensors_TemperatureSensor_16
#  138 : ECC_Monitoring_Sensors_WaterPressureSensors_WaterPresureSensor_1
#  139 : ECC_Monitoring_Sensors_WaterPressureSensors_WaterPresureSensor_2
#  140 : ECC_Monitoring_Shutter_Down_Contactor1
#  141 : ECC_Monitoring_Shutter_Error
#  142 : ECC_Monitoring_Shutter_GeneralStatus
#  143 : ECC_Monitoring_Shutter_Up_Contactor1
#  144 : ECC_Monitoring_Spares_Analog_AI_01
#  145 : ECC_Monitoring_Spares_Analog_AI_02
#  146 : ECC_Monitoring_Spares_Analog_AI_03
#  147 : ECC_Monitoring_Spares_Analog_AI_04
#  148 : ECC_Monitoring_Spares_Digital_DI_08
#  149 : ECC_Monitoring_Transition_Countdown
#
# ---          Collection - EVB_week           ---
#    0 : CompleteEvents
#    1 : OutputEvents
#    2 : RunNumber
#
# ---          Collection - TIB_week           ---
#    0 : TIB_Alarm_AlarmVector
#    1 : TIB_BUSY_TIB_busy_time
#    2 : TIB_ConnectionStatus
#    3 : TIB_DACOptical_Neighbour5
#    4 : TIB_Delays_Delay2
#    5 : TIB_Delays_DelayLocal
#    6 : TIB_Rates_BUSYRate
#    7 : TIB_Rates_CalibrationRate
#    8 : TIB_Rates_CameraRate
#    9 : TIB_Rates_CollectedRate
#   10 : TIB_Rates_In1Rate
#   11 : TIB_Rates_In2Rate
#   12 : TIB_Rates_In3Rate
#   13 : TIB_Rates_In4Rate
#   14 : TIB_Rates_LocalRate
#   15 : TIB_Rates_PedestalRate
#   16 : TIB_Rates_SoftrigRate
#   17 : TIB_Rates_SpheRate
#   18 : TIB_Rates_StereoRate
#   19 : TIB_ReadState
#   20 : TIB_TIB_TXclient_alive
#   21 : TIB_Temperature
#   22 : TIB_TriggerMode_ModeMask

# %% [markdown]
# # Parameters
# * Search for the variable names in before produced lists and fill the names.
# * If no variables to be input, fill with **`None`**
# * Set start and stop time for the query

# %%
# IDs of the variables to be displayed
variable_1_caco = "ECC_Monitoring_Sensors_TemperatureSensors_TemperatureAverage"
variable_1_tcu  = "ECC_Monitoring_Sensors_TemperatureSensors_TemperatureSensor_"
variable_2_caco = "CBOX_Temperature"
variable_2_tcu  = None

# Time for the query
tstart = datetime.fromisoformat("2024-03-17-16:00:00")
tstop  = datetime.fromisoformat("2024-03-18-10:40:00")

# %% [markdown]
# #### Getting the DB entries

# %%
out_1_caco = utils.get_caco_entries(client_caco, variable_1_caco, dict_caco_names, tstart=tstart, tstop=tstop)
date_1_caco, value_1_caco = out_1_caco["time"], out_1_caco["value"]

out_2_caco = utils.get_caco_entries(client_caco, variable_2_caco, dict_caco_names, tstart=tstart, tstop=tstop)
date_2_caco, value_2_caco = out_2_caco["time"], out_2_caco["value"]

out_1_tcu = lst1_mongodb_example.get_entries(client_tcu, variable_1_tcu, astropy_time=False, tstart=tstart, tstop=tstop)
date_1_tcu, value_1_tcu = out_1_tcu["time"], out_1_tcu["value"]

out_2_tcu = lst1_mongodb_example.get_entries(client_tcu, variable_2_tcu, astropy_time=False, tstart=tstart, tstop=tstop)
date_2_tcu, value_2_tcu = out_2_tcu["time"], out_2_tcu["value"]

# Ceck if something is empty
for var, vals, name in zip([variable_1_caco, variable_1_tcu, variable_2_caco, variable_2_tcu], [value_1_caco, value_1_tcu, value_2_caco, value_2_tcu], ["CaCo", "TCU ", "CaCo", "TCU "]):
    if var != None:
        print(f"For {name} {var:50} : {len(vals):5} entries found")

# Some variables are in bunches, so for this case, only taking first element
if len(value_1_tcu) > 0:
    if len(value_1_tcu[0]) > 1:
        print(f"\nFor TCU, {variable_1_tcu} is in buches of {len(value_1_tcu[0])}, in this case taking first element.")
        value_1_tcu = np.array(value_1_tcu)[:,1]
if len(value_2_tcu) > 0:
    if len(value_2_tcu[0]) > 1:
        print(f"For TCU; {variable_2_tcu} is in buches of {len(value_2_tcu[0])}, in this case taking first element.")
        value_2_tcu = np.array(value_2_tcu)[:,1]
        
        
        
# Check if var1 is empty but var2 is filled
# In this case we fill the "1" inforation with "2" data
if (variable_1_tcu == None and variable_1_caco == None) and (variable_2_tcu != None or variable_2_caco != None):
    
    variable_1_caco, variable_2_caco = variable_2_caco, variable_1_caco
    variable_1_tcu, variable_2_tcu   = variable_2_tcu, variable_1_tcu
    out_1_caco, out_2_caco = out_2_caco, out_1_caco
    out_1_tcu, out_2_tcu   = out_2_tcu, out_1_tcu
    value_1_caco, value_2_caco = value_2_caco, value_1_caco
    value_1_tcu, value_2_tcu   = value_2_tcu, value_1_tcu
    date_1_caco, date_2_caco = date_2_caco, date_1_caco
    date_1_tcu, date_2_tcu   = date_2_tcu, date_1_tcu

# %% [markdown]
# #### Plotting

# %%
fig, ax = plt.subplots(figsize=(16,3.4))
if len(value_2_tcu) > 0 or len(value_2_caco) > 0:
    axt = ax.twinx()
    axt.set_ylabel(variable_2_tcu)
    axt.set_ylabel(variable_2_caco)

ax.plot(date_1_caco, value_1_caco, ds="steps-post", c="darkblue", lw=1.5,
        label=f"CaCo: {out_1_caco['name']}")
ax.plot(date_1_tcu, value_1_tcu, ds="steps-post", c="royalblue", ls="--", lw=1.5,
        label=f"TCU: {out_1_tcu['name']}")

axt.plot(date_2_caco, value_2_caco, ds="steps-post", c="crimson", lw=1.5,
         label=f"CaCo: {out_2_caco['name']}")
axt.plot(date_2_tcu, value_2_tcu, ds="steps-post", c="maroon", ls=":", lw=1.5,
         label=f"TCU: {out_2_tcu['name']}")
    

ax.set_ylabel(variable_1_tcu)
ax.set_ylabel(variable_1_caco)
ax.legend(loc=6, prop={'size': 7})
if len(value_2_tcu) > 0 or len(value_2_caco) > 0:
    axt.legend(loc=7, prop={'size': 7})
ax.grid(color="lightgray")

# Plotting limits
lim_m, lim_M = min(min(date_1_caco), min(date_1_tcu)), max(max(date_1_caco), max(date_1_tcu))

timespan = lim_M - lim_m
ax.set_xlim(lim_m, lim_M)
ax.set_title(f"{tstart} to {tstop}")
utils.format_time_ticks_axes(ax, lim_m, lim_M, timespan)

ax.yaxis.label.set_color("b")
ax.tick_params(axis='y', colors="b")
axt.yaxis.label.set_color("crimson")
axt.tick_params(axis='y', colors="crimson")

# plt.savefig(f"output.png", dpi=300, bbox_inches='tight')
plt.show()
